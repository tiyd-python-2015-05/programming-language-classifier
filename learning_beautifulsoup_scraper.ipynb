# %%
from scraper import *

# %%
tc = make_data(['Temperature_conversion'])

# %%
tc.shape
# Out:
# (65, 2)

# %%
pn = make_data(['Perfect_numbers'])
pn.shape
# Out:
# (125, 2)

# %%
code_snippets = pd.DataFrame(columns=([0, 1]))
code_snippets
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []

# %%
code_snippets.append(tc).
# Out:
#              0                                                  1
# 0         text  : KtoC \ n -- n\t273.15 n:- ; : KtoF \ n -- n\...
# 1          ada  with Ada.Float_Text_IO, Ada.Text_IO;  use Ada....
# 2         text  voidshow(integer symbol, real temperature){   ...
# 3   autohotkey  MsgBox, % "Kelvin:`t`t 21.00 K`n"        . "Ce...
# 4          awk  # syntax: AWK -f TEMPERATURE_CONVERSION.AWKBEG...
# 5          awk  # usage: gawk -f temperature_conversion.awk  i...
# 6         text   10 REM TRANSLATION OF AWK VERSION20 INPUT "KE...
# 7         text   do  print "Kelvin degrees (>=0): ";  input K ...
# 8         text   REPEAT  INPUT "Kelvin degrees (>=0): " KUNTIL...
# 9         text  ( ( rational2fixedpoint  =   minus fixedpointn...
# 10           c  #include <stdio.h>#include <stdlib.h> double k...
# 11         cpp   #include <iostream>#include <iomanip> //-----...
# 12      csharp  using System; namespace TemperatureConversion{...
# 13     clojure  (defn to-celsius [k]  (- k 273.15))(defn to-fa...
# 14       cobol         IDENTIFICATION DIVISION.       PROGRAM-...
# 15        lisp   (defun to-celsius (k)   (- k 273.15))(defun t...
# 16           d  double kelvinToCelsius(in double k) pure nothr...
# 17      delphi   program Temperature; {$APPTYPE CONSOLE} uses ...
# 18      erlang  % Implemented by Arjun Sunel-module(temp_conv)...
# 19        text   include std/console.e atom Kwhile 1 do\tK = p...
# 20        text  A1 : KelvinB1 : CelsiusC1 : FahrenheitD1 : Ran...
# 21        text   # convert from Kelvinநிரல்பாகம் கெல்வின்_இருந...
# 22      fsharp   // Define units of measure[<Measure>] type k[...
# 23     fortran  Program Temperature  implicit none   real :: k...
# 24          go  package main import (    "fmt"    "os"    "str...
# 25     haskell   main = do  putStrLn "Please enter temperature...
# 26      unicon  procedure main(A)    k := A[1] | 21.00    writ...
# 27           j     NB.  Temp conversions are all linear polyno...
# 28           j     NB. Format matrix for printing & tag each  ...
# 29        java  public class TemperatureConversion {    public...
# ..         ...                                                ...
# 35        text  tempConvert[t_] :=Grid[Transpose@{{"K", "C", "...
# 36        text  П7\t0\t,\t8\t*\tП8\tИП7\t9\t*\t5/\t3\t2\t+\tП9...
# 37       ocaml  fun KtoC n = n - 273.15;fun KtoF n = n * 1.8 -...
# 38     netrexx  /* NetRexx */options replace format comments j...
# 39        text  import rdstdin, strutils, strfmt while true:  ...
# 40      objeck   class Temperature {  function : Main(args : S...
# 41        objc  #import <Foundation/Foundation.h> int main(int...
# 42       ocaml   let print_temp s t =  print_string s;  print_...
# 43        text  : kelvinToCelsius { 273.15 - }: kelvinToFahren...
# 44      parigp               f(x)=[x,x-273.15,1.8*x-459.67,1.8*x]
# 45        perl  my %scale = (    Celcius    => { factor => 1  ...
# 46       perl6  while my $answer = prompt 'Temperature: ' {   ...
# 47         php  error_reporting(E_ALL & ~ ( E_NOTICE | E_WARNI...
# 48        text  (scl 2) (de convertKelvin (Kelvin)   (for X   ...
# 49        text                               (convertKelvin 21.0)
# 50         pli  *process source attributes xref; /* PL/I *****...
# 51      python  >>> while True:\tk = float(input('K ? '))\tpri...
# 52      python  >>> toK = {'C': (lambda c: c + 273.15),       ...
# 53        text  #lang racket(define (converter temp init final...
# 54        rexx  /*REXX program converts temperatures for a num...
# 55        ruby  module TempConvert   FROM_TEMP_SCALE_TO_K =   ...
# 56        ruby  TempConvert.kelvin_to_celsius 100 #=> -173.15T...
# 57        text  [loop]input "Kelvin Degrees";kelvinif kelvin <...
# 58       scala  object TemperatureConversion extends App {   d...
# 59        text  $ include "seed7_05.s7i";  include "float.s7i"...
# 60         tcl  proc temps {k} {    set c [expr {$k - 273.15}]...
# 61         tcl  puts -nonewline "Enter a temperature in K: "fl...
# 62        text  include c:\cxpl\codes;real K, C, F, R;[ChOut(0...
# 63        text  K:=ask(0,"Kelvin: ").toFloat();println("K %.2f...
# 64     zxbasic  10 REM Translation of traditional basic versio...
#
# [65 rows x 2 columns]

# %%
code_snippets.append(pn).shape
# Out:
# (125, 2)

# %%
url = 'http://rosettacode.org/wiki/Hailstone_sequence'

# %%
code = scrape_data(url)
codes = pull_code_from_soup(code)
pd.DataFrame(codes)
# Out:
#               0                                                  1
# 0          abap   CLASS lcl_hailstone DEFINITION.  PUBLIC SECTI...
# 1          lisp  (defun hailstone (len)    (loop for x = len   ...
# 2           ada  with Ada.Text_IO; use Ada.Text_IO;procedure ha...
# 3           ada  package Hailstones is   type Integer_Sequence ...
# 4           ada  package body Hailstones is   function Create_S...
# 5           ada  with Ada.Text_IO;with Hailstones; procedure Ma...
# 6          text  voidprint_hailstone(integer h){    list l;    ...
# 7       algol68  MODE LINT = # LONG ... # INT; PROC hailstone =...
# 8          text  seq←hailstone n;next⍝ Returns the hailstone se...
# 9          text   5↑hailstone 2727 82 41 124 62 ¯5↑hailstone 27...
# 10   autohotkey  ; Submitted by MasterFocus --- http://tiny.cc/...
# 11       autoit   $Hail = Hailstone(27)ConsoleWrite("Sequence-L...
# 12          awk   #!/usr/bin/awk -ffunction hailstone(v, verbos...
# 13         text  10 HOME 100 N = 27110 GOSUB 400"HAILSTONE120 D...
# 14         text        seqlen% = FNhailstone(27, TRUE)      PRI...
# 15           lb  print "Part 1: Create a routine to generate th...
# 16         text    function Hailstone(sys *n)'=================...
# 17    purebasic  NewList Hailstones.i() ; Make a linked list to...
# 18         text  print "Part 1: Create a routine to generate th...
# 19          dos  @echo offsetlocal enabledelayedexpansionif "%1...
# 20          dos                >hailstone.cmd 2020 10 5 16 8 4 2 1
# 21         text                   &>:.:1-|  >3*^ @  |%2: < V>2/>+
# 22         text  (  ( hailstone  =   L len    .   !arg:?L      ...
# 23         text  >,[    [        ----------[            >>>[>>>...
# 24         text                                              27111
# 25         text  hailstone = { num |  sequence = [num]  while {...
# 26         text   blsq ) 27{^^^^2.%{3.*1.+}\/{2./}\/ie}{1!=}w!b...
# 27            c  #include <stdio.h>#include <stdlib.h> int hail...
# 28            c  #include <stdio.h> #define N 10000000#define C...
# 29       csharp  using System;using System.Collections.Generic;...
# ..          ...                                                ...
# 139      python  def hailstone(n):    seq = [n]    while n>1:  ...
# 140        text  ### PART 1:makeHailstone <- function(n){  hseq...
# 141        text   #lang racket (define hailstone  (let ([t (mak...
# 142        rexx  /*REXX pgm tests a number and a range for hail...
# 143        rexx  /*REXX pgm tests a number and a range for hail...
# 144        ruby  def hailstone n  seq = [n]  until n == 1    n ...
# 145        ruby  module Hailstone  ListNode = Struct.new(:value...
# 146        text  use std::vec::Vec; fn hailstone(mut n : int) -...
# 147         sas   * Create a routine to generate the hailstone ...
# 148       scala  object HailstoneSequence extends App {  def ha...
# 149      scheme  (define (collatz n)(if (= n 1) '(1)(cons n (co...
# 150        text  function x=hailstone(n)    // iterative defini...
# 151        text  $ include "seed7_05.s7i"; const func array int...
# 152        ruby  func hailstone(n) {    var a = [n];    while (...
# 153   smalltalk  Object subclass: Sequences [  Sequences class ...
# 154   smalltalk  |r|r := Sequences hailstone: 27.  "hailstone '...
# 155        text   func hailstone(var n:Int) -> [Int] {     var ...
# 156         tcl  proc hailstone n {    while 1 {\tlappend seq $...
# 157        text  prompt NN→M: 0→X: 1→LWhile L=1X+1→XDisp MIf M=...
# 158        text  prompt N0→A:0→Bfor(I,1,N)I→M: 0→X: 1→LWhile L=...
# 159        text  @(do (defun hailstone (n)       (cons n       ...
# 160        bash  #!/bin/bash# seq is the array genereated by ha...
# 161        bash  # Outputs a hailstone sequence from $1, with o...
# 162        text  # Outputs a hailstone sequence from !:1, with ...
# 163        text  #import std#import nat hail = @iNC ~&h~=1->x ^...
# 164          vb  Option ExplicitDim flag As Boolean ' true to p...
# 165       vbnet  Module HailstoneSequence    Sub Main()        ...
# 166        text  include c:\cxpl\codes;  \intrinsic 'code' decl...
# 167        text  fcn collatz(n,z=L()){ z.append(n); if(n==1) re...
# 168        text  [2..0d100_000].pump(Void,  // loop n from 2 to...
#
# [169 rows x 2 columns]

# %%
hs = make_data(['Hailstone_sequence'])

# %%
tc = make_data(['Temperature_conversion'])

# %%
hs.shape, tc.shape
# Out:
# ((169, 2), (65, 2))

# %%
hs = hs.append(tc)

# %%
pn = make_data(['Perfect_numbers'])

# %%
hs.append(pn).shape
# Out:
# (359, 2)

# %%
pn = make_data(['Perfect_numbers', 'Temperature_conversion', 'Hailstone_sequence'])

# %%
pn.shape
# Out:
# (359, 2)

# %%
for item in task_list:
    item.replace(" ", "_")
    append.
print(task_list)
# Out:
# ['24 game', '24 game/Solve9', '9 billion names of God the integer', '99 Bottles of BeerA', 'A+B', 'ABC Problem', 'Abstract type', 'Abundant, deficient and perfect number classifications', 'Accumulator factory', 'Ackermann function', 'Active Directory/Connect', 'Active Directory/Search for a user', 'Active object', 'Add a variable to a class instance at runtime', 'Address of a variable', 'AKS test for primes', 'Align columns', 'Aliquot sequence classifications', 'Almost prime', 'Amb', 'Amicable pairs', 'Anagrams', 'Anagrams/Deranged anagrams', 'Animate a pendulum', 'Animation', 'Anonymous recursion', 'Append a record to the end of a text file', 'Apply a callback to an array', 'Arbitrary-precision integers (included)', 'Arena storage pool', 'Arithmetic evaluation', 'Arithmetic-geometric mean', 'Arithmetic-geometric mean/Calculate Pi', 'Arithmetic/Complex', 'Arithmetic/Integer', 'Arithmetic/Rational', 'Array concatenation', 'Arrays', 'Assertions', 'Associative array/Creation', 'Associative array/Iteration', 'Atomic updates', 'Average loop length', 'Averages/Arithmetic mean', 'Averages/Mean angle', 'Averages/Mean time of day', 'Averages/Median', 'Averages/Mode', 'Averages/Pythagorean means', 'Averages/Root mean square', 'Averages/Simple moving averageB', 'Balanced brackets', 'Balanced ternary', "Benford's law", 'Bernoulli numbers', 'Best shuffle', 'Binary digits', 'Binary search', 'Binary strings', 'Bitcoin/address validation', 'Bitcoin/public point to address', 'Bitmap', "Bitmap/Bresenham's line algorithm", 'Bitmap/Bézier curves/Cubic', 'Bitmap/Bézier curves/Quadratic', 'Bitmap/Flood fill', 'Bitmap/Histogram', 'Bitmap/Midpoint circle algorithm', 'Bitmap/PPM conversion through a pipe', 'Bitmap/Read a PPM file', 'Bitmap/Read an image through a pipe', 'Bitmap/Write a PPM file', 'Bitwise IO', 'Bitwise operations', 'Boolean values', 'Box the compass', 'Break OO privacy', 'Brownian tree', 'Bulls and cows', 'Bulls and cows/PlayerC', 'Caesar cipher', 'Calendar', 'Calendar - for "REAL" programmers', 'Call a foreign-language function', 'Call a function', 'Call a function in a shared library', 'Call an object method', 'Canny edge detector', 'Carmichael 3 strong pseudoprimes', 'Case-sensitivity of identifiers', 'Casting out nines', 'Catalan numbers', "Catalan numbers/Pascal's triangle", 'Catamorphism', 'Catmull–Clark subdivision surface', 'Character codes', 'Chat server', 'Check Machin-like formulas', 'Check that file exists', 'Checkpoint synchronization', 'Chinese remainder theorem', 'Cholesky decomposition', 'Circles of given radius through two points', 'Classes', 'Closest-pair problem', 'Closures/Value capture', 'Collections', 'Color of a screen pixel', 'Color quantization', 'Colour bars/Display', 'Colour pinstripe/Display', 'Colour pinstripe/Printer', 'Combinations', 'Combinations and permutations', 'Combinations with repetitions', 'Comma quibbling', 'Command-line arguments', 'Comments', "Compare sorting algorithms' performance", 'Compile-time calculation', 'Compound data type', 'Concurrent computing', 'Conditional structures', 'Conjugate transpose', 'Constrained genericity', 'Constrained random points on a circle', 'Continued fraction', 'Continued fraction/Arithmetic/Construct from rational number', 'Continued fraction/Arithmetic/G(matrix NG, Contined Fraction N)', 'Continued fraction/Arithmetic/G(matrix NG, Contined Fraction N1, Contined Fraction N2)', 'Convert decimal number to rational', "Conway's Game of Life", 'Copy a string', 'Count in factors', 'Count in octal', 'Count occurrences of a substring', 'Count the coins', 'CRC-32', 'Create a file', 'Create a file on magnetic tape', 'Create a two-dimensional array at runtime', 'Create an HTML table', 'Create an object at a given address', 'CSV data manipulation', 'CSV to HTML translation', 'Currying', 'Cut a rectangleD', 'Date format', 'Date manipulation', 'Day of the week', 'Deal cards for FreeCell', 'Death Star', 'Deconvolution/1D', 'Deconvolution/2D+', 'Deepcopy', 'Define a primitive ...

# %%
def scrape_tasks(url):
    req = urllib.request.Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    content = urllib.request.urlopen(req).read()
    soup = BeautifulSoup(content)
    return soup.find_all( "a")#, class_="li")
links = scrape_tasks('http://rosettacode.org/wiki/Category:Programming_Tasks')
# Out:
# [<a id="top"></a>,
#  <a href="#mw-head">navigation</a>,
#  <a href="#p-search">search</a>,
#  <a href="/wiki/Rosetta_Code:Add_a_Task" title="Rosetta Code:Add a Task">guidelines</a>,
#  <a href="/wiki/Category_talk:Programming_Tasks" title="Category talk:Programming Tasks">discussion for this page</a>,
#  <a class="external text" href="http://rosettacode.org/wiki/Category:Draft_Programming_Tasks" rel="nofollow">Category:Draft Programming Tasks</a>,
#  <a href="/wiki/100_doors" title="100 doors">100 doors</a>,
#  <a href="/wiki/24_game" title="24 game">24 game</a>,
#  <a href="/wiki/24_game/Solve" title="24 game/Solve">24 game/Solve</a>,
#  <a href="/wiki/9_billion_names_of_God_the_integer" title="9 billion names of God the integer">9 billion names of God the integer</a>,
#  <a href="/wiki/99_Bottles_of_Beer" title="99 Bottles of Beer">99 Bottles of Beer</a>,
#  <a href="/wiki/A%2BB" title="A+B">A+B</a>,
#  <a href="/wiki/ABC_Problem" title="ABC Problem">ABC Problem</a>,
#  <a href="/wiki/Abstract_type" title="Abstract type">Abstract type</a>,
#  <a href="/wiki/Abundant,_deficient_and_perfect_number_classifications" title="Abundant, deficient and perfect number classifications">Abundant, deficient and perfect number classifications</a>,
#  <a href="/wiki/Accumulator_factory" title="Accumulator factory">Accumulator factory</a>,
#  <a href="/wiki/Ackermann_function" title="Ackermann function">Ackermann function</a>,
#  <a href="/wiki/Active_Directory/Connect" title="Active Directory/Connect">Active Directory/Connect</a>,
#  <a href="/wiki/Active_Directory/Search_for_a_user" title="Active Directory/Search for a user">Active Directory/Search for a user</a>,
#  <a href="/wiki/Active_object" title="Active object">Active object</a>,
#  <a href="/wiki/Add_a_variable_to_a_class_instance_at_runtime" title="Add a variable to a class instance at runtime">Add a variable to a class instance at runtime</a>,
#  <a href="/wiki/Address_of_a_variable" title="Address of a variable">Address of a variable</a>,
#  <a href="/wiki/AKS_test_for_primes" title="AKS test for primes">AKS test for primes</a>,
#  <a href="/wiki/Align_columns" title="Align columns">Align columns</a>,
#  <a href="/wiki/Aliquot_sequence_classifications" title="Aliquot sequence classifications">Aliquot sequence classifications</a>,
#  <a href="/wiki/Almost_prime" title="Almost prime">Almost prime</a>,
#  <a href="/wiki/Amb" title="Amb">Amb</a>,
#  <a href="/wiki/Amicable_pairs" title="Amicable pairs">Amicable pairs</a>,
#  <a href="/wiki/Anagrams" title="Anagrams">Anagrams</a>,
#  <a href="/wiki/Anagrams/Deranged_anagrams" title="Anagrams/Deranged anagrams">Anagrams/Deranged anagrams</a>,
#  <a href="/wiki/Animate_a_pendulum" title="Animate a pendulum">Animate a pendulum</a>,
#  <a href="/wiki/Animation" title="Animation">Animation</a>,
#  <a href="/wiki/Anonymous_recursion" title="Anonymous recursion">Anonymous recursion</a>,
#  <a href="/wiki/Append_a_record_to_the_end_of_a_text_file" title="Append a record to the end of a text file">Append a record to the end of a text file</a>,
#  <a href="/wiki/Apply_a_callback_to_an_array" title="Apply a callback to an array">Apply a callback to an array</a>,
#  <a href="/wiki/Arbitrary-precision_integers_(included)" title="Arbitrary-precision integers (included)">Arbitrary-precision integers (included)</a>,
#  <a href="/wiki/Arena_storage_pool" title="Arena storage pool">Arena storage pool</a>,
#  <a href="/wiki/Arithmetic_evaluation" title="Arithmetic evaluation">Arithmetic evaluation</a>,
#  <a href="/wiki/Arithmetic-geometric_mean" title="Arithmetic-geometric mean">Arithmetic-geometric mean</a>,
#  <a href="/wiki/Arithmetic-geometric_mean/Calculate_Pi" title="Arithmetic-geometric mean/Calculate Pi">Arithmetic-geometric mean/Calculate Pi</a>,
#  <a href="/wiki/Arithmetic/Complex" title="Arithmetic/Complex">Arithmetic/Complex</a>,
#  <a href="/wiki/Arithmetic/Integer" title="Arithmetic/Integer">Arithmetic/Integer</a>,
#  <a href="/wiki/Arithmetic/Rational" title="Arithmetic/Rational">Arithmetic/Rational</a>,
#  <a href="/wiki/Array_concatenation" title="Array concatenation">Array concatenation</a>,
#  <a href="/wiki/Arrays" title="Arrays">Arrays</a>,
#  <a href="/wiki/Assertions" title="Assertions">Assertions</a>,
#  <a href="/wiki/Associative_array/Creation" title="Associative array/Creation">Associative array/Creation</a>,
#  <a href="/wiki/Associative_array/Iteration" title="Associative array/Iteration">Associative array/Iteration</a>,
#  <a href="/wiki/Atomic_updates" title="Atomic updates">Atomic updates</a>,
#  <a href="/wiki/Average_loop_length" title="Average loop length">Average loop length</a>,
#  <a href="/wiki/Averages/Arithmetic_mean" title="Averages/Arithmetic mean">Averages/Arithmetic mean</a>,
#  <a href="/wiki/Averages/Mean_angle" title="Averages/Mean angle">Averages/Mean angle</a>,
#  <a href="/wiki/Averages/Mean_time_of_day" title="Averages/Mean time of day">Averages/Mean time of day</a>,
#  <a href="/wiki/Averages/Median" title="Averages/Median">Averages/Median</a>,
#  <a href="/wiki/Averages/Mode" title="Averages/Mode">Averages/Mode</a>,
#  <a href="/wiki/Averages/Pythagorean_means" title="Averages/Pythagorean means">Averages/Pythagorean means</a>,
#  <a href="/wiki/Averages/Root_mean_square" title="Averages/Root mean square">Averages/Root mean square</a>,
#  <a href="/wiki/Averages/Simple_moving_average" title="Averages/Simple moving average">Averages/Simple moving average</a>,
#  <a href="/wiki/Balanced_brackets" title="Balanced brackets">Balanced brackets</a>,
#  <a href="/wiki/Balanced_ternary" title="Balanced ternary">Balanced ternary</a>,
#  <a href="/wiki/Benford%27s_law" title="Benford's law">Benford's law</a>,
#  <a href="/wiki/Bernoulli_numbers" title="Bernoulli numbers">Bernoulli numbers</a>,
#  <a href="/wiki/Best_shuffle" title="Best shuffle">Best shuffle</a>,
#  <a href="/wiki/Binary_digits" title="Binary digits">Binary digits</a>,
#  <a href="/wiki/Binary_search" title="Binary search">Binary search</a>,
#  <a href="/wiki/Binary_strings" title="Binary strings">Binary strings</a>,
#  <a href="/wiki/Bitcoin/address_validation" title="Bitcoin/address validation">Bitcoin/address validation</a>,
#  <a href="/wiki/Bitcoin/public_point_to_address" title="Bitcoin/public point to address">Bitcoin/public point to address</a>,
#  <a href="/wiki/Bitmap" title="Bitmap">Bitmap</a>,
#  <a href="/wiki/Bitmap/Bresenham%27s_line_algorithm" title="Bitmap/Bresenham's line algorithm">Bitmap/Bresenham's line algorithm</a>,
#  <a href="/wiki/Bitmap/B%C3%A9zier_curves/Cubic" title="Bitmap/Bézier curves/Cubic">Bitmap/Bézier curves/Cubic</a>,
#  <a href="/wiki/Bitmap/B%C3%A9zier_curves/Quadratic" title="Bitmap/Bézier curves/Quadratic">Bitmap/Bézier curves/Quadratic</a>,
#  <a href="/wiki/Bitmap/Flood_fill" title="Bitmap/Flood fill">Bitmap/Flood fill</a>,
#  <a href="/wiki/Bitmap/Histogram" title="Bitmap/Histogram">Bitmap/Histogram</a>,
#  <a href="/wiki/Bitmap/Midpoint_circle_algorithm" title="Bitmap/Midpoint circle algorithm">Bitmap/Midpoint circle algorithm</a>,
#  <a href="/wiki/Bitmap/PPM_conversion_through_a_pipe" title="Bitmap/PPM conversion through a pipe">Bitmap/PPM conversion through a pipe</a>,
#  <a href="/wiki/Bitmap/Read_a_PPM_file" title="Bitmap/Read a PPM file">Bitmap/Read a PPM file</a>,
#  <a href="/wiki/Bitmap/Read_an_image_through_a_pipe" title="Bitmap/Read an image through a pipe">Bitmap/Read an image through a pipe</a>,
#  <a href="/wiki/Bitmap/Write_a_PPM_file" title="Bitmap/Write a PPM file">Bitmap/Write a PPM file</a>,
#  <a href="/wiki/Bitwise_IO" title="Bitwise IO">Bitwise IO</a>,
#  <a href="/wiki/Bitwise_operations" title="Bitwise operations">Bitwise operations</a>,
#  <a href="/wiki/Boolean_values" title="Boolean values">Boolean values</a>,
#  <a href="/wiki/Box_the_compass" title="Box the compass">Box the compass</a>,
#  <a href="/wiki/Break_OO_privacy" title="Break OO privacy">Break OO privacy</a>,
#  <a href="/wiki/Brownian_tree" title="Brownian tree">Brownian tree</a>,
#  <a href="/wiki/Bulls_and_cows" title="Bulls and cows">Bulls and cows</a>,
#  <a href="/wiki/Bulls_and_cows/Player" title="Bulls and cows/Player">Bulls and cows/Player</a>,
#  <a href="/wiki/Caesar_cipher" title="Caesar cipher">Caesar cipher</a>,
#  <a href="/wiki/Calendar" title="Calendar">Calendar</a>,
#  <a href="/wiki/Calendar_-_for_%22REAL%22_programmers" title='Calendar - for "REAL" programmers'>Calendar - for "REAL" programmers</a>,
#  <a href="/wiki/Call_a_foreign-language_function" title="Call a foreign-language function">Call a foreign-language function</a>,
#  <a href="/wiki/Call_a_function" title="Call a function">Call a function</a>,
#  <a href="/wiki/Call_a_function_in_a_shared_library" title="Call a function in a shared library">Call a function in a shared library</a>,
#  <a href="/wiki/Call_an_object_method" title="Call an object method">Call an object method</a>,
#  <a href="/wiki/Canny_edge_detector" title="Canny edge detector">Canny edge detector</a>,
#  <a href="/wiki/Carmichael_3_strong_pseudoprimes" title="Carmichael 3 strong pseudoprimes">Carmichael 3 strong pseudoprimes</a>,
#  <a href="/wiki/Case-sensitivity_of_identifiers" title="Case-sensitivity of identifiers">Case-sensitivity of identifiers</a>,
#  <a href="/wiki/Casting_out_nines" title="Casting out nines">Casting out nines</a>,
#  <a href="/wiki/Catalan_numbers" title="Catalan numbers">Catalan numbers</a>,
#  <a href="/wiki/Catalan_numbers/Pascal%27s_triangle" title="Catalan numbers/Pascal's triangle">Catalan numbers/Pascal's triangle</a>,
#  <a href="/wiki/Catamorphism" title="Catamorphism">Catamorphism</a>,
#  <a href="/wiki/Catmull%E2%80%93Clark_subdivision_surface" title="Catmull–Clark subdivision surface">Catmull–Clark subdivision surface</a>,
#  <a href="/wiki/Character_codes" title="Character codes">Character codes</a>,
#  <a href="/wiki/Chat_server" title="Chat server">Chat server</a>,
#  <a href="/wiki/Check_Machin-like_formulas" title="Check Machin-like formulas">Check Machin-like formulas</a>,
#  <a href="/wiki/Check_that_file_exists" title="Check that file exists">Check that file exists</a>,
#  <a href="/wiki/Checkpoint_synchronization" title="Checkpoint synchronization">Checkpoint synchronization</a>,
#  <a href="/wiki/Chinese_remainder_theorem" title="Chinese remainder theorem">Chinese remainder theorem</a>,
#  <a href="/wiki/Cholesky_decomposition" title="Cholesky decomposition">Cholesky decomposition</a>,
#  <a href="/wiki/Circles_of_given_radius_through_two_points" title="Circles of given radius through two points">Circles of given radius through two points</a>,
#  <a href="/wiki/Classes" title="Classes">Classes</a>,
#  <a href="/wiki/Closest-pair_problem" title="Closest-pair problem">Closest-pair problem</a>,
#  <a href="/wiki/Closures/Value_capture" title="Closures/Value capture">Closures/Value capture</a>,
#  <a href="/wiki/Collections" title="Collections">Collections</a>,
#  <a href="/wiki/Color_of_a_screen_pixel" title="Color of a screen pixel">Color of a screen pixel</a>,
#  <a href="/wiki/Color_quantization" title="Color quantization">Color quantization</a>,
#  <a href="/wiki/Colour_bars/Display" title="Colour bars/Display">Colour bars/Display</a>,
#  <a href="/wiki/Colour_pinstripe/Display" title="Colour pinstripe/Display">Colour pinstripe/Display</a>,
#  <a href="/wiki/Colour_pinstripe/Printer" title="Colour pinstripe/Printer">Colour pinstripe/Printer</a>,
#  <a href="/wiki/Combinations" title="Combinations">Combinations</a>,
#  <a href="/wiki/Combinations_and_permutations" title="Combinations and permutations">Combinations and permutations</a>,
#  <a href="/wiki/Combinations_with_repetitions" title="Combinations with repetitions">Combinations with repetitions</a>,
#  <a href="/wiki/Comma_quibbling" title="Comma quibbling">Comma quibbling</a>,
#  <a href="/wiki/Command-line_arguments" title="Command-line arguments">Command-line arguments</a>,
#  <a href="/wiki/Comments" title="Comments">Comments</a>,
#  <a href="/wiki/Compare_sorting_algorithms%27_performance" title="Compare sorting algorithms' performance">Compare sorting algorithms' performance</a>,
#  <a href="/wiki/Compile-time_calculation" title="Compile-time calculation">Compile-time calculation</a>,
#  <a href="/wiki/Compound_data_type" title="Compound data type">Compound data type</a>,
#  <a href="/wiki/Concurrent_computing" title="Concurrent computing">Concurrent computing</a>,
#  <a href="/wiki/Conditional_structures" title="Conditional structures">Conditional structures</a>,
#  <a href="/wiki/Conjugate_transpose" title="Conjugate transpose">Conjugate transpose</a>,
#  <a href="/wiki/Constrained_genericity" title="Constrained genericity">Constrained genericity</a>,
#  <a href="/wiki/Constrained_random_points_on_a_circle" title="Constrained random points on a circle">Constrained random points on a circle</a>,
#  <a href="/wiki/Continued_fraction" title="Continued fraction">Continued fraction</a>,
#  <a href="/wiki/Continued_fraction/Arithmetic/Construct_from_rational_number" title="Continued fraction/Arithmetic/Construct from rational number">Continued fraction/Arithmetic/Construct from rational number</a>,
#  <a href="/wiki/Continued_fraction/Arithmetic/G(matrix_NG,_Contined_Fraction_N)" title="Continued fraction/Arithmetic/G(matrix NG, Contined Fraction N)">Continued fraction/Arithmetic/G(matrix NG, Contined Fraction N)</a>,
#  <a href="/wiki/Continued_fraction/Arithmetic/G(matrix_NG,_Contined_Fraction_N1,_Contined_Fraction_N2)" title="Continued fraction/Arithmetic/G(matrix NG, Contined Fraction N1, Contined Fraction N2)">Continued fraction/Arithmetic/G(matrix NG, Contined Fraction N1, Contined Fraction N2)</a>,
#  <a href="/wiki/Convert_decimal_number_to_rational" title="Convert decimal number to rational">Convert decimal number to rational</a>,
#  <a href="/wiki/Conway%27s_Game_of_Life" title="Conway's Game of Life">Conway's Game of Life</a>,
#  <a href="/wiki/Copy_a_string" title="Copy a string">Copy a string</a>,
#  <a href="/wiki/Count_in_factors" title="Count in factors">Count in factors</a>,
#  <a href="/wiki/Count_in_octal" title="Count in octal">Count in octal</a>,
#  <a href="/wiki/Count_occurrences_of_a_substring" title="Count occurrences of a substring">Count occurrences of a substring</a>,
#  <a href="/wiki/Count_the_coins" title="Count the coins">Count the coins</a>,
#  <a href="/wiki/CRC-32" title="CRC-32">CRC-32</a>,
#  <a href="/wiki/Create_a_file" title="Create a file">Create a file</a>,
#  <a href="/wiki/Create_a_file_on_magnetic_tape" title="Create a file on magnetic tape">Create a file on magnetic tape</a>,
#  <a href="/wiki/Create_a_two-dimensional_array_at_runtime" title="Create a two-dimensional array at runtime">Create a two-dimensional array at runtime</a>,
#  <a href="/wiki/Create_an_HTML_table" title="Create an HTML table">Create an HTML table</a>,
#  <a href="/wiki/Create_an_object_at_a_given_address" title="Create an object at a given address">Create an object at a given address</a>,
#  <a href="/wiki/CSV_data_manipulation" title="CSV data manipulation">CSV data manipulation</a>,
#  <a href="/wiki/CSV_to_HTML_translation" title="CSV to HTML translation">CSV to HTML translation</a>,
#  <a href="/wiki/Currying" title="Currying">Currying</a>,
#  <a href="/wiki/Cut_a_rectangle" title="Cut a rectangle">Cut a rectangle</a>,
#  <a href="/wiki/Date_format" title="Date format">Date format</a>,
#  <a href="/wiki/Date_manipulation" title="Date manipulation">Date manipulation</a>,
#  <a href="/wiki/Day_of_the_week" title="Day of the week">Day of the week</a>,
#  <a href="/wiki/Deal_cards_for_FreeCell" title="Deal cards for FreeCell">Deal cards for FreeCell</a>,
#  <a href="/wiki/Death_Star" title="Death Star">Death Star</a>,
#  <a href="/wiki/Deconvolution/1D" title="Deconvolution/1D">Deconvolution/1D</a>,
#  <a href="/wiki/Deconvolution/2D%2B" title="Deconvolution/2D+">Deconvolution/2D+</a>,
#  <a href="/wiki/Deepcopy" title="Deepcopy">Deepcopy</a>,
#  <a href="/wiki/Define_a_primitive_data_type" title="Define a primitive data type">Define a primitive data type</a>,
#  <a href="/wiki/Delegates" title="Delegates">Delegates</a>,
#  <a href="/wiki/Delete_a_file" title="Delete a file">Delete a file</a>,
#  <a href="/wiki/Detect_division_by_zero" title="Detect division by zero">Detect division by zero</a>,
#  <a href="/wiki/Determine_if_a_string_is_numeric" title="Determine if a string is numeric">Determine if a string is numeric</a>,
#  <a href="/wiki/Determine_if_only_one_instance_is_running" title="Determine if only one instance is running">Determine if only one instance is running</a>,
#  <a href="/wiki/Digital_root" title="Digital root">Digital root</a>,
#  <a href="/wiki/Digital_root/Multiplicative_digital_root" title="Digital root/Multiplicative digital root">Digital root/Multiplicative digital root</a>,
#  <a href="/wiki/Dinesman%27s_multiple-dwelling_problem" title="Dinesman's multiple-dwelling problem">Dinesman's multiple-dwelling problem</a>,
#  <a href="/wiki/Dining_philosophers" title="Dining philosophers">Dining philosophers</a>,
#  <a href="/wiki/Discordian_date" title="Discordian date">Discordian date</a>,
#  <a href="/wiki/Distributed_programming" title="Distributed programming">Distributed programming</a>,
#  <a href="/wiki/DNS_query" title="DNS query">DNS query</a>,
#  <a href="/wiki/Documentation" title="Documentation">Documentation</a>,
#  <a href="/wiki/Dot_product" title="Dot product">Dot product</a>,
#  <a href="/wiki/Doubly-linked_list/Definition" title="Doubly-linked list/Definition">Doubly-linked list/Definition</a>,
#  <a href="/wiki/Doubly-linked_list/Element_definition" title="Doubly-linked list/Element definition">Doubly-linked list/Element definition</a>,
#  <a href="/wiki/Doubly-linked_list/Element_insertion" title="Doubly-linked list/Element insertion">Doubly-linked list/Element insertion</a>,
#  <a href="/wiki/Doubly-linked_list/Traversal" title="Doubly-linked list/Traversal">Doubly-linked list/Traversal</a>,
#  <a href="/wiki/Dragon_curve" title="Dragon curve">Dragon curve</a>,
#  <a href="/wiki/Draw_a_clock" title="Draw a clock">Draw a clock</a>,
#  <a href="/wiki/Draw_a_cuboid" title="Draw a cuboid">Draw a cuboid</a>,
#  <a href="/wiki/Draw_a_sphere" title="Draw a sphere">Draw a sphere</a>,
#  <a href="/wiki/Dutch_national_flag_problem" title="Dutch national flag problem">Dutch national flag problem</a>,
#  <a href="/wiki/Dynamic_variable_names" title="Dynamic variable names">Dynamic variable names</a>,
#  <a href="/wiki/Echo_server" title="Echo server">Echo server</a>,
#  <a href="/wiki/Element-wise_operations" title="Element-wise operations">Element-wise operations</a>,
#  <a href="/wiki/Empty_directory" title="Empty directory">Empty directory</a>,
#  <a href="/wiki/Empty_program" title="Empty program">Empty program</a>,
#  <a href="/wiki/Empty_string" title="Empty string">Empty string</a>,
#  <a href="/wiki/Enforced_immutability" title="Enforced immutability">Enforced immutability</a>,
#  <a href="/wiki/Entropy" title="Entropy">Entropy</a>,
#  <a href="/wiki/Enumerations" title="Enumerations">Enumerations</a>,
#  <a href="/wiki/Environment_variables" title="Environment variables">Environment variables</a>,
#  <a href="/wiki/Equilibrium_index" title="Equilibrium index">Equilibrium index</a>,
#  <a href="/wiki/Ethiopian_multiplication" title="Ethiopian multiplication">Ethiopian multiplication</a>,
#  <a href="/wiki/Euler_method" title="Euler method">Euler method</a>,
#  <a href="/wiki/Euler%27s_sum_of_powers_conjecture" title="Euler's sum of powers conjecture">Euler's sum of powers conjecture</a>,
#  <a href="/wiki/Evaluate_binomial_coefficients" title="Evaluate binomial coefficients">Evaluate binomial coefficients</a>,
#  <a href="/wiki/Even_or_odd" title="Even or odd">Even or odd</a>,
#  <a href="/wiki/Events" title="Events">Events</a>,
#  <a href="/wiki/Evolutionary_algorithm" title="Evolutionary algorithm">Evolutionary algorithm</a>,
#  <a href="/wiki/Exceptions" title="Exceptions">Exceptions</a>,
#  <a href="/wiki/Exceptions/Catch_an_exception_thrown_in_a_nested_call" title="Exceptions/Catch an exception thrown in a nested call">Exceptions/Catch an exception thrown in a nested call</a>,
#  <a href="/wiki/Executable_library" title="Executable library">Executable library</a>,
#  <a href="/wiki/Execute_a_Markov_algorithm" title="Execute a Markov algorithm">Execute a Markov algorithm</a>,
#  <a href="/wiki/Execute_a_system_command" title="Execute a system command">Execute a system command</a>,
#  <a href="/wiki/Execute_Brain****" title="Execute Brain****">Execute Brain****</a>,
#  <a href="/wiki/Execute_HQ9%2B" title="Execute HQ9+">Execute HQ9+</a>,
#  <a href="/wiki/Execute_SNUSP" title="Execute SNUSP">Execute SNUSP</a>,
#  <a href="/wiki/Exponentiation_operator" title="Exponentiation operator">Exponentiation operator</a>,
#  <a href="/wiki/Extend_your_language" title="Extend your language">Extend your language</a>,
#  <a href="/wiki/Extensible_prime_generator" title="Extensible prime generator">Extensible prime generator</a>,
#  <a href="/wiki/Extreme_floating_point_values" title="Extreme floating point values">Extreme floating point values</a>,
#  <a href="/wiki/Factorial" title="Factorial">Factorial</a>,
#  <a href="/wiki/Factors_of_a_Mersenne_number" title="Factors of a Mersenne number">Factors of a Mersenne number</a>,
#  <a href="/wiki/Factors_of_an_integer" title="Factors of an integer">Factors of an integer</a>,
#  <a href="/wiki/Fast_Fourier_transform" title="Fast Fourier transform">Fast Fourier transform</a>,
#  <a href="/wiki/Fibonacci_n-step_number_sequences" title="Fibonacci n-step number sequences">Fibonacci n-step number sequences</a>,
#  <a href="/wiki/Fibonacci_sequence" title="Fibonacci sequence">Fibonacci sequence</a>,
#  <a href="/wiki/Fibonacci_word" title="Fibonacci word">Fibonacci word</a>,
#  <a href="/wiki/Fibonacci_word/fractal" title="Fibonacci word/fractal">Fibonacci word/fractal</a>,
#  <a href="/wiki/File_input/output" title="File input/output">File input/output</a>,
#  <a href="/wiki/File_modification_time" title="File modification time">File modification time</a>,
#  <a href="/wiki/File_size" title="File size">File size</a>,
#  <a href="/wiki/Filter" title="Filter">Filter</a>,
#  <a href="/wiki/Find_common_directory_path" title="Find common directory path">Find common directory path</a>,
#  <a href="/wiki/Find_largest_left_truncatable_prime_in_a_given_base" title="Find largest left truncatable prime in a given base">Find largest left truncatable prime in a given base</a>,
#  <a href="/wiki/Find_limit_of_recursion" title="Find limit of recursion">Find limit of recursion</a>,
#  <a href="/wiki/Find_the_last_Sunday_of_each_month" title="Find the last Sunday of each month">Find the last Sunday of each month</a>,
#  <a href="/wiki/Find_the_missing_permutation" title="Find the missing permutation">Find the missing permutation</a>,
#  <a href="/wiki/First_class_environments" title="First class environments">First class environments</a>,
#  <a href="/wiki/First-class_functions" title="First-class functions">First-class functions</a>,
#  <a href="/wiki/First-class_functions/Use_numbers_analogously" title="First-class functions/Use numbers analogously">First-class functions/Use numbers analogously</a>,
#  <a href="/wiki/Five_weekends" title="Five weekends">Five weekends</a>,
#  <a href="/wiki/FizzBuzz" title="FizzBuzz">FizzBuzz</a>,
#  <a href="/wiki/Flatten_a_list" title="Flatten a list">Flatten a list</a>,
#  <a href="/wiki/Flipping_bits_game" title="Flipping bits game">Flipping bits game</a>,
#  <a href="/wiki/Flow-control_structures" title="Flow-control structures">Flow-control structures</a>,
#  <a href="/wiki/Floyd%27s_triangle" title="Floyd's triangle">Floyd's triangle</a>,
#  <a href="/wiki/Forest_fire" title="Forest fire">Forest fire</a>,
#  <a href="/wiki/Fork" title="Fork">Fork</a>,
#  <a href="/wiki/Formal_power_series" title="Formal power series">Formal power series</a>,
#  <a href="/wiki/Formatted_numeric_output" title="Formatted numeric output">Formatted numeric output</a>,
#  <a href="/wiki/Forward_difference" title="Forward difference">Forward difference</a>,
#  <a href="/wiki/Four_bit_adder" title="Four bit adder">Four bit adder</a>,
#  <a href="/wiki/Fractal_tree" title="Fractal tree">Fractal tree</a>,
#  <a href="/wiki/Fractran" title="Fractran">Fractran</a>,
#  <a href="/wiki/Function_composition" title="Function composition">Function composition</a>,
#  <a href="/wiki/Function_definition" title="Function definition">Function definition</a>,
#  <a href="/wiki/Function_frequency" title="Function frequency">Function frequency</a>,
#  <a href="/wiki/Function_prototype" title="Function prototype">Function prototype</a>,
#  <a href="/wiki/Galton_box_animation" title="Galton box animation">Galton box animation</a>,
#  <a href="/wiki/Gamma_function" title="Gamma function">Gamma function</a>,
#  <a href="/wiki/Gaussian_elimination" title="Gaussian elimination">Gaussian elimination</a>,
#  <a href="/wiki/Generate_Chess960_starting_position" title="Generate Chess960 starting position">Generate Chess960 starting position</a>,
#  <a href="/wiki/Generate_lower_case_ASCII_alphabet" title="Generate lower case ASCII alphabet">Generate lower case ASCII alphabet</a>,
#  <a href="/wiki/Generator/Exponential" title="Generator/Exponential">Generator/Exponential</a>,
#  <a href="/wiki/Generic_swap" title="Generic swap">Generic swap</a>,
#  <a href="/wiki/Globally_replace_text_in_several_files" title="Globally replace text in several files">Globally replace text in several files</a>,
#  <a href="/wiki/Go_Fish" title="Go Fish">Go Fish</a>,
#  <a href="/wiki/Gray_code" title="Gray code">Gray code</a>,
#  <a href="/wiki/Grayscale_image" title="Grayscale image">Grayscale image</a>,
#  <a href="/wiki/Greatest_common_divisor" title="Greatest common divisor">Greatest common divisor</a>,
#  <a href="/wiki/Greatest_element_of_a_list" title="Greatest element of a list">Greatest element of a list</a>,
#  <a href="/wiki/Greatest_subsequential_sum" title="Greatest subsequential sum">Greatest subsequential sum</a>,
#  <a href="/wiki/Greyscale_bars/Display" title="Greyscale bars/Display">Greyscale bars/Display</a>,
#  <a href="/wiki/Guess_the_number" title="Guess the number">Guess the number</a>,
#  <a href="/wiki/Guess_the_number/With_feedback" title="Guess the number/With feedback">Guess the number/With feedback</a>,
#  <a href="/wiki/Guess_the_number/With_feedback_(player)" title="Guess the number/With feedback (player)">Guess the number/With feedback (player)</a>,
#  <a href="/wiki/GUI_component_interaction" title="GUI component interaction">GUI component interaction</a>,
#  <a href="/wiki/GUI_enabling/disabling_of_controls" title="GUI enabling/disabling of controls">GUI enabling/disabling of controls</a>,
#  <a href="/wiki/GUI/Maximum_window_dimensions" title="GUI/Maximum window dimensions">GUI/Maximum window dimensions</a>,
#  <a href="/wiki/Hailstone_sequence" title="Hailstone sequence">Hailstone sequence</a>,
#  <a href="/wiki/Hamming_numbers" title="Hamming numbers">Hamming numbers</a>,
#  <a href="/wiki/Handle_a_signal" title="Handle a signal">Handle a signal</a>,
#  <a href="/wiki/Happy_numbers" title="Happy numbers">Happy numbers</a>,
#  <a href="/wiki/Harshad_or_Niven_series" title="Harshad or Niven series">Harshad or Niven series</a>,
#  <a href="/wiki/Hash_from_two_arrays" title="Hash from two arrays">Hash from two arrays</a>,
#  <a href="/wiki/Hash_join" title="Hash join">Hash join</a>,
#  <a href="/wiki/Haversine_formula" title="Haversine formula">Haversine formula</a>,
#  <a href="/wiki/Hello_world/Graphical" title="Hello world/Graphical">Hello world/Graphical</a>,
#  <a href="/wiki/Hello_world/Line_printer" title="Hello world/Line printer">Hello world/Line printer</a>,
#  <a href="/wiki/Hello_world/Newbie" title="Hello world/Newbie">Hello world/Newbie</a>,
#  <a href="/wiki/Hello_world/Newline_omission" title="Hello world/Newline omission">Hello world/Newline omission</a>,
#  <a href="/wiki/Hello_world/Standard_error" title="Hello world/Standard error">Hello world/Standard error</a>,
#  <a href="/wiki/Hello_world/Text" title="Hello world/Text">Hello world/Text</a>,
#  <a href="/wiki/Hello_world/Web_server" title="Hello world/Web server">Hello world/Web server</a>,
#  <a href="/wiki/Here_document" title="Here document">Here document</a>,
#  <a href="/wiki/Heronian_triangles" title="Heronian triangles">Heronian triangles</a>,
#  <a href="/wiki/Hickerson_series_of_almost_integers" title="Hickerson series of almost integers">Hickerson series of almost integers</a>,
#  <a href="/wiki/Higher-order_functions" title="Higher-order functions">Higher-order functions</a>,
#  <a href="/wiki/History_variables" title="History variables">History variables</a>,
#  <a href="/wiki/Hofstadter_Figure-Figure_sequences" title="Hofstadter Figure-Figure sequences">Hofstadter Figure-Figure sequences</a>,
#  <a href="/wiki/Hofstadter_Q_sequence" title="Hofstadter Q sequence">Hofstadter Q sequence</a>,
#  <a href="/wiki/Hofstadter-Conway_$10,000_sequence" title="Hofstadter-Conway $10,000 sequence">Hofstadter-Conway $10,000 sequence</a>,
#  <a href="/wiki/Holidays_related_to_Easter" title="Holidays related to Easter">Holidays related to Easter</a>,
#  <a href="/wiki/Honeycombs" title="Honeycombs">Honeycombs</a>,
#  <a href="/wiki/Horizontal_sundial_calculations" title="Horizontal sundial calculations">Horizontal sundial calculations</a>,
#  <a href="/wiki/Horner%27s_rule_for_polynomial_evaluation" title="Horner's rule for polynomial evaluation">Horner's rule for polynomial evaluation</a>,
#  <a href="/wiki/Host_introspection" title="Host introspection">Host introspection</a>,
#  <a href="/wiki/Hostname" title="Hostname">Hostname</a>,
#  <a href="/wiki/Hough_transform" title="Hough transform">Hough transform</a>,
#  <a href="/wiki/HTTP" title="HTTP">HTTP</a>,
#  <a href="/wiki/HTTPS" title="HTTPS">HTTPS</a>,
#  <a href="/wiki/HTTPS/Authenticated" title="HTTPS/Authenticated">HTTPS/Authenticated</a>,
#  <a href="/wiki/HTTPS/Client-authenticated" title="HTTPS/Client-authenticated">HTTPS/Client-authenticated</a>,
#  <a href="/wiki/Huffman_coding" title="Huffman coding">Huffman coding</a>,
#  <a href="/wiki/I_before_E_except_after_C" title="I before E except after C">I before E except after C</a>,
#  <a href="/wiki/IBAN" title="IBAN">IBAN</a>,
#  <a href="/wiki/Identity_matrix" title="Identity matrix">Identity matrix</a>,
#  <a href="/wiki/Image_convolution" title="Image convolution">Image convolution</a>,
#  <a href="/wiki/Image_noise" title="Image noise">Image noise</a>,
#  <a href="/wiki/Include_a_file" title="Include a file">Include a file</a>,
#  <a href="/wiki/Increment_a_numerical_string" title="Increment a numerical string">Increment a numerical string</a>,
#  <a href="/wiki/Infinity" title="Infinity">Infinity</a>,
#  <a href="/wiki/Inheritance/Multiple" title="Inheritance/Multiple">Inheritance/Multiple</a>,
#  <a href="/wiki/Inheritance/Single" title="Inheritance/Single">Inheritance/Single</a>,
#  <a href="/wiki/Input_loop" title="Input loop">Input loop</a>,
#  <a href="/wiki/Integer_comparison" title="Integer comparison">Integer comparison</a>,
#  <a href="/wiki/Integer_overflow" title="Integer overflow">Integer overflow</a>,
#  <a href="/wiki/Integer_sequence" title="Integer sequence">Integer sequence</a>,
#  <a href="/wiki/Interactive_programming" title="Interactive programming">Interactive programming</a>,
#  <a href="/wiki/Introspection" title="Introspection">Introspection</a>,
#  <a href="/wiki/Inverted_index" title="Inverted index">Inverted index</a>,
#  <a href="/wiki/Inverted_syntax" title="Inverted syntax">Inverted syntax</a>,
#  <a href="/wiki/Iterated_digits_squaring" title="Iterated digits squaring">Iterated digits squaring</a>,
#  <a href="/wiki/Jensen%27s_Device" title="Jensen's Device">Jensen's Device</a>,
#  <a href="/wiki/JortSort" title="JortSort">JortSort</a>,
#  <a href="/wiki/Josephus_problem" title="Josephus problem">Josephus problem</a>,
#  <a href="/wiki/Joystick_position" title="Joystick position">Joystick position</a>,
#  <a href="/wiki/JSON" title="JSON">JSON</a>,
#  <a href="/wiki/Jump_anywhere" title="Jump anywhere">Jump anywhere</a>,
#  <a href="/wiki/K-d_tree" title="K-d tree">K-d tree</a>,
#  <a href="/wiki/K-means%2B%2B_clustering" title="K-means++ clustering">K-means++ clustering</a>,
#  <a href="/wiki/Kaprekar_numbers" title="Kaprekar numbers">Kaprekar numbers</a>,
#  <a href="/wiki/Keyboard_input/Flush_the_keyboard_buffer" title="Keyboard input/Flush the keyboard buffer">Keyboard input/Flush the keyboard buffer</a>,
#  <a href="/wiki/Keyboard_input/Keypress_check" title="Keyboard input/Keypress check">Keyboard input/Keypress check</a>,
#  <a href="/wiki/Keyboard_input/Obtain_a_Y_or_N_response" title="Keyboard input/Obtain a Y or N response">Keyboard input/Obtain a Y or N response</a>,
#  <a href="/wiki/Keyboard_macros" title="Keyboard macros">Keyboard macros</a>,
#  <a href="/wiki/Knapsack_problem/0-1" title="Knapsack problem/0-1">Knapsack problem/0-1</a>,
#  <a href="/wiki/Knapsack_problem/Bounded" title="Knapsack problem/Bounded">Knapsack problem/Bounded</a>,
#  <a href="/wiki/Knapsack_problem/Continuous" title="Knapsack problem/Continuous">Knapsack problem/Continuous</a>,
#  <a href="/wiki/Knapsack_problem/Unbounded" title="Knapsack problem/Unbounded">Knapsack problem/Unbounded</a>,
#  <a href="/wiki/Knight%27s_tour" title="Knight's tour">Knight's tour</a>,
#  <a href="/wiki/Knuth_shuffle" title="Knuth shuffle">Knuth shuffle</a>,
#  <a href="/wiki/Knuth%27s_algorithm_S" title="Knuth's algorithm S">Knuth's algorithm S</a>,
#  <a href="/wiki/Langton%27s_ant" title="Langton's ant">Langton's ant</a>,
#  <a href="/wiki/Largest_int_from_concatenated_ints" title="Largest int from concatenated ints">Largest int from concatenated ints</a>,
#  <a href="/wiki/Last_Friday_of_each_month" title="Last Friday of each month">Last Friday of each month</a>,
#  <a href="/wiki/Last_letter-first_letter" title="Last letter-first letter">Last letter-first letter</a>,
#  <a href="/wiki/Leap_year" title="Leap year">Leap year</a>,
#  <a href="/wiki/Least_common_multiple" title="Least common multiple">Least common multiple</a>,
#  <a href="/wiki/Left_factorials" title="Left factorials">Left factorials</a>,
#  <a href="/wiki/Letter_frequency" title="Letter frequency">Letter frequency</a>,
#  <a href="/wiki/Levenshtein_distance" title="Levenshtein distance">Levenshtein distance</a>,
#  <a href="/wiki/Linear_congruential_generator" title="Linear congruential generator">Linear congruential generator</a>,
#  <a href="/wiki/List_comprehensions" title="List comprehensions">List comprehensions</a>,
#  <a href="/wiki/Literals/Floating_point" title="Literals/Floating point">Literals/Floating point</a>,
#  <a href="/wiki/Literals/Integer" title="Literals/Integer">Literals/Integer</a>,
#  <a href="/wiki/Literals/String" title="Literals/String">Literals/String</a>,
#  <a href="/wiki/Logical_operations" title="Logical operations">Logical operations</a>,
#  <a href="/wiki/Long_multiplication" title="Long multiplication">Long multiplication</a>,
#  <a href="/wiki/Longest_common_subsequence" title="Longest common subsequence">Longest common subsequence</a>,
#  <a href="/wiki/Longest_increasing_subsequence" title="Longest increasing subsequence">Longest increasing subsequence</a>,
#  <a href="/wiki/Longest_string_challenge" title="Longest string challenge">Longest string challenge</a>,
#  <a href="/wiki/Look-and-say_sequence" title="Look-and-say sequence">Look-and-say sequence</a>,
#  <a href="/wiki/Loop_over_multiple_arrays_simultaneously" title="Loop over multiple arrays simultaneously">Loop over multiple arrays simultaneously</a>,
#  <a href="/wiki/Loops/Break" title="Loops/Break">Loops/Break</a>,
#  <a href="/wiki/Loops/Continue" title="Loops/Continue">Loops/Continue</a>,
#  <a href="/wiki/Loops/Do-while" title="Loops/Do-while">Loops/Do-while</a>,
#  <a href="/wiki/Loops/Downward_for" title="Loops/Downward for">Loops/Downward for</a>,
#  <a href="/wiki/Loops/For" title="Loops/For">Loops/For</a>,
#  <a href="/wiki/Loops/For_with_a_specified_step" title="Loops/For with a specified step">Loops/For with a specified step</a>,
#  <a href="/wiki/Loops/Foreach" title="Loops/Foreach">Loops/Foreach</a>,
#  <a href="/wiki/Loops/Infinite" title="Loops/Infinite">Loops/Infinite</a>,
#  <a href="/wiki/Loops/N_plus_one_half" title="Loops/N plus one half">Loops/N plus one half</a>,
#  <a href="/wiki/Loops/Nested" title="Loops/Nested">Loops/Nested</a>,
#  <a href="/wiki/Loops/While" title="Loops/While">Loops/While</a>,
#  <a href="/wiki/LU_decomposition" title="LU decomposition">LU decomposition</a>,
#  <a href="/wiki/Lucas-Lehmer_test" title="Lucas-Lehmer test">Lucas-Lehmer test</a>,
#  <a href="/wiki/Ludic_numbers" title="Ludic numbers">Ludic numbers</a>,
#  <a href="/wiki/Luhn_test_of_credit_card_numbers" title="Luhn test of credit card numbers">Luhn test of credit card numbers</a>,
#  <a href="/wiki/LZW_compression" title="LZW compression">LZW compression</a>,
#  <a href="/wiki/Machine_code" title="Machine code">Machine code</a>,
#  <a href="/wiki/Mad_Libs" title="Mad Libs">Mad Libs</a>,
#  <a href="/wiki/Magic_squares_of_odd_order" title="Magic squares of odd order">Magic squares of odd order</a>,
#  <a href="/wiki/Main_step_of_GOST_28147-89" title="Main step of GOST 28147-89">Main step of GOST 28147-89</a>,
#  <a href="/wiki/Make_directory_path" title="Make directory path">Make directory path</a>,
#  <a href="/wiki/Man_or_boy_test" title="Man or boy test">Man or boy test</a>,
#  <a href="/wiki/Mandelbrot_set" title="Mandelbrot set">Mandelbrot set</a>,
#  <a href="/wiki/Map_range" title="Map range">Map range</a>,
#  <a href="/wiki/Matrix_arithmetic" title="Matrix arithmetic">Matrix arithmetic</a>,
#  <a href="/wiki/Matrix_multiplication" title="Matrix multiplication">Matrix multiplication</a>,
#  <a href="/wiki/Matrix_transposition" title="Matrix transposition">Matrix transposition</a>,
#  <a href="/wiki/Matrix-exponentiation_operator" title="Matrix-exponentiation operator">Matrix-exponentiation operator</a>,
#  <a href="/wiki/Maximum_triangle_path_sum" title="Maximum triangle path sum">Maximum triangle path sum</a>,
#  <a href="/wiki/Maze_generation" title="Maze generation">Maze generation</a>,
#  <a href="/wiki/Maze_solving" title="Maze solving">Maze solving</a>,
#  <a href="/wiki/MD4" title="MD4">MD4</a>,
#  <a href="/wiki/MD5" title="MD5">MD5</a>,
#  <a href="/wiki/MD5/Implementation" title="MD5/Implementation">MD5/Implementation</a>,
#  <a href="/wiki/Median_filter" title="Median filter">Median filter</a>,
#  <a href="/wiki/Memory_allocation" title="Memory allocation">Memory allocation</a>,
#  <a href="/wiki/Memory_layout_of_a_data_structure" title="Memory layout of a data structure">Memory layout of a data structure</a>,
#  <a href="/wiki/Menu" title="Menu">Menu</a>,
#  <a href="/wiki/Metaprogramming" title="Metaprogramming">Metaprogramming</a>,
#  <a href="/wiki/Metered_concurrency" title="Metered concurrency">Metered concurrency</a>,
#  <a href="/wiki/Metronome" title="Metronome">Metronome</a>,
#  <a href="/wiki/Middle_three_digits" title="Middle three digits">Middle three digits</a>,
#  <a href="/wiki/Miller-Rabin_primality_test" title="Miller-Rabin primality test">Miller-Rabin primality test</a>,
#  <a href="/wiki/Minesweeper_game" title="Minesweeper game">Minesweeper game</a>,
#  <a href="/wiki/Modular_exponentiation" title="Modular exponentiation">Modular exponentiation</a>,
#  <a href="/wiki/Modular_inverse" title="Modular inverse">Modular inverse</a>,
#  <a href="/wiki/Monte_Carlo_methods" title="Monte Carlo methods">Monte Carlo methods</a>,
#  <a href="/wiki/Monty_Hall_problem" title="Monty Hall problem">Monty Hall problem</a>,
#  <a href="/wiki/Morse_code" title="Morse code">Morse code</a>,
#  <a href="/wiki/Mouse_position" title="Mouse position">Mouse position</a>,
#  <a href="/wiki/Move-to-front_algorithm" title="Move-to-front algorithm">Move-to-front algorithm</a>,
#  <a href="/wiki/Multifactorial" title="Multifactorial">Multifactorial</a>,
#  <a href="/wiki/Multiple_distinct_objects" title="Multiple distinct objects">Multiple distinct objects</a>,
#  <a href="/wiki/Multiple_regression" title="Multiple regression">Multiple regression</a>,
#  <a href="/wiki/Multiplication_tables" title="Multiplication tables">Multiplication tables</a>,
#  <a href="/wiki/Multiplicative_order" title="Multiplicative order">Multiplicative order</a>,
#  <a href="/wiki/Multisplit" title="Multisplit">Multisplit</a>,
#  <a href="/wiki/Munching_squares" title="Munching squares">Munching squares</a>,
#  <a href="/wiki/Mutual_recursion" title="Mutual recursion">Mutual recursion</a>,
#  <a href="/wiki/N%27th" title="N'th">N'th</a>,
#  <a href="/wiki/N-queens_problem" title="N-queens problem">N-queens problem</a>,
#  <a href="/wiki/Named_parameters" title="Named parameters">Named parameters</a>,
#  <a href="/wiki/Narcissist" title="Narcissist">Narcissist</a>,
#  <a href="/wiki/Narcissistic_decimal_number" title="Narcissistic decimal number">Narcissistic decimal number</a>,
#  <a href="/wiki/Natural_sorting" title="Natural sorting">Natural sorting</a>,
#  <a href="/wiki/Nautical_bell" title="Nautical bell">Nautical bell</a>,
#  <a href="/wiki/Non-continuous_subsequences" title="Non-continuous subsequences">Non-continuous subsequences</a>,
#  <a href="/wiki/Non-decimal_radices/Convert" title="Non-decimal radices/Convert">Non-decimal radices/Convert</a>,
#  <a href="/wiki/Non-decimal_radices/Input" title="Non-decimal radices/Input">Non-decimal radices/Input</a>,
#  <a href="/wiki/Non-decimal_radices/Output" title="Non-decimal radices/Output">Non-decimal radices/Output</a>,
#  <a href="/wiki/Nth_root" title="Nth root">Nth root</a>,
#  <a href="/wiki/Null_object" title="Null object">Null object</a>,
#  <a href="/wiki/Number_names" title="Number names">Number names</a>,
#  <a href="/wiki/Number_reversal_game" title="Number reversal game">Number reversal game</a>,
#  <a href="/wiki/Numeric_error_propagation" title="Numeric error propagation">Numeric error propagation</a>,
#  <a href="/wiki/Numerical_integration" title="Numerical integration">Numerical integration</a>,
#  <a href="/wiki/Numerical_integration/Gauss-Legendre_Quadrature" title="Numerical integration/Gauss-Legendre Quadrature">Numerical integration/Gauss-Legendre Quadrature</a>,
#  <a href="/wiki/Object_serialization" title="Object serialization">Object serialization</a>,
#  <a href="/wiki/Odd_word_problem" title="Odd word problem">Odd word problem</a>,
#  <a href="/wiki/Old_lady_swallowed_a_fly" title="Old lady swallowed a fly">Old lady swallowed a fly</a>,
#  <a href="/wiki/OLE_Automation" title="OLE Automation">OLE Automation</a>,
#  <a href="/wiki/One_of_n_lines_in_a_file" title="One of n lines in a file">One of n lines in a file</a>,
#  <a href="/wiki/One-dimensional_cellular_automata" title="One-dimensional cellular automata">One-dimensional cellular automata</a>,
#  <a href="/wiki/OpenGL" title="OpenGL">OpenGL</a>,
#  <a href="/wiki/Operator_precedence" title="Operator precedence">Operator precedence</a>,
#  <a href="/wiki/Optional_parameters" title="Optional parameters">Optional parameters</a>,
#  <a href="/wiki/Order_disjoint_list_items" title="Order disjoint list items">Order disjoint list items</a>,
#  <a href="/wiki/Order_two_numerical_lists" title="Order two numerical lists">Order two numerical lists</a>,
#  <a href="/wiki/Ordered_Partitions" title="Ordered Partitions">Ordered Partitions</a>,
#  <a href="/wiki/Ordered_words" title="Ordered words">Ordered words</a>,
#  <a href="/wiki/Palindrome_detection" title="Palindrome detection">Palindrome detection</a>,
#  <a href="/wiki/Pangram_checker" title="Pangram checker">Pangram checker</a>,
#  <a href="/wiki/Paraffins" title="Paraffins">Paraffins</a>,
#  <a href="/wiki/Parallel_calculations" title="Parallel calculations">Parallel calculations</a>,
#  <a href="/wiki/Parametric_polymorphism" title="Parametric polymorphism">Parametric polymorphism</a>,
#  <a href="/wiki/Parametrized_SQL_statement" title="Parametrized SQL statement">Parametrized SQL statement</a>,
#  <a href="/wiki/Parse_an_IP_Address" title="Parse an IP Address">Parse an IP Address</a>,
#  <a href="/wiki/Parsing/RPN_calculator_algorithm" title="Parsing/RPN calculator algorithm">Parsing/RPN calculator algorithm</a>,
#  <a href="/wiki/Parsing/RPN_to_infix_conversion" title="Parsing/RPN to infix conversion">Parsing/RPN to infix conversion</a>,
#  <a href="/wiki/Parsing/Shunting-yard_algorithm" title="Parsing/Shunting-yard algorithm">Parsing/Shunting-yard algorithm</a>,
#  <a href="/wiki/Partial_function_application" title="Partial function application">Partial function application</a>,
#  <a href="/wiki/Pascal_matrix_generation" title="Pascal matrix generation">Pascal matrix generation</a>,
#  <a href="/wiki/Pascal%27s_triangle" title="Pascal's triangle">Pascal's triangle</a>,
#  <a href="/wiki/Pascal%27s_triangle/Puzzle" title="Pascal's triangle/Puzzle">Pascal's triangle/Puzzle</a>,
#  <a href="/wiki/Pattern_matching" title="Pattern matching">Pattern matching</a>,
#  <a href="/wiki/Penney%27s_game" title="Penney's game">Penney's game</a>,
#  <a href="/wiki/Percentage_difference_between_images" title="Percentage difference between images">Percentage difference between images</a>,
#  <a href="/wiki/Percolation/Bond_percolation" title="Percolation/Bond percolation">Percolation/Bond percolation</a>,
#  <a href="/wiki/Percolation/Mean_cluster_density" title="Percolation/Mean cluster density">Percolation/Mean cluster density</a>,
#  <a href="/wiki/Percolation/Mean_run_density" title="Percolation/Mean run density">Percolation/Mean run density</a>,
#  <a href="/wiki/Percolation/Site_percolation" title="Percolation/Site percolation">Percolation/Site percolation</a>,
#  <a href="/wiki/Perfect_numbers" title="Perfect numbers">Perfect numbers</a>,
#  <a href="/wiki/Permutation_test" title="Permutation test">Permutation test</a>,
#  <a href="/wiki/Permutations" title="Permutations">Permutations</a>,
#  <a href="/wiki/Permutations_by_swapping" title="Permutations by swapping">Permutations by swapping</a>,
#  <a href="/wiki/Permutations/Derangements" title="Permutations/Derangements">Permutations/Derangements</a>,
#  <a href="/wiki/Permutations/Rank_of_a_permutation" title="Permutations/Rank of a permutation">Permutations/Rank of a permutation</a>,
#  <a href="/wiki/Pernicious_numbers" title="Pernicious numbers">Pernicious numbers</a>,
#  <a href="/wiki/Phrase_reversals" title="Phrase reversals">Phrase reversals</a>,
#  <a href="/wiki/Pi" title="Pi">Pi</a>,
#  <a href="/wiki/Pick_random_element" title="Pick random element">Pick random element</a>,
#  <a href="/wiki/Pig_the_dice_game" title="Pig the dice game">Pig the dice game</a>,
#  <a href="/wiki/Pig_the_dice_game/Player" title="Pig the dice game/Player">Pig the dice game/Player</a>,
#  <a href="/wiki/Pinstripe/Display" title="Pinstripe/Display">Pinstripe/Display</a>,
#  <a href="/wiki/Pinstripe/Printer" title="Pinstripe/Printer">Pinstripe/Printer</a>,
#  <a href="/wiki/Play_recorded_sounds" title="Play recorded sounds">Play recorded sounds</a>,
#  <a href="/wiki/Playing_cards" title="Playing cards">Playing cards</a>,
#  <a href="/wiki/Plot_coordinate_pairs" title="Plot coordinate pairs">Plot coordinate pairs</a>,
#  <a href="/wiki/Pointers_and_references" title="Pointers and references">Pointers and references</a>,
#  <a href="/wiki/Polymorphic_copy" title="Polymorphic copy">Polymorphic copy</a>,
#  <a href="/wiki/Polymorphism" title="Polymorphism">Polymorphism</a>,
#  <a href="/wiki/Polynomial_long_division" title="Polynomial long division">Polynomial long division</a>,
#  <a href="/wiki/Polynomial_regression" title="Polynomial regression">Polynomial regression</a>,
#  <a href="/wiki/Power_set" title="Power set">Power set</a>,
#  <a href="/wiki/Pragmatic_directives" title="Pragmatic directives">Pragmatic directives</a>,
#  <a href="/wiki/Price_fraction" title="Price fraction">Price fraction</a>,
#  <a href="/wiki/Primality_by_trial_division" title="Primality by trial division">Primality by trial division</a>,
#  <a href="/wiki/Prime_decomposition" title="Prime decomposition">Prime decomposition</a>,
#  <a href="/wiki/Primes_-_allocate_descendants_to_their_ancestors" title="Primes - allocate descendants to their ancestors">Primes - allocate descendants to their ancestors</a>,
#  <a href="/wiki/Priority_queue" title="Priority queue">Priority queue</a>,
#  <a href="/wiki/Probabilistic_choice" title="Probabilistic choice">Probabilistic choice</a>,
#  <a href="/wiki/Problem_of_Apollonius" title="Problem of Apollonius">Problem of Apollonius</a>,
# ...
#  <a href="/wiki/Statistics/Basic" title="Statistics/Basic">Statistics/Basic</a>,
#  <a href="/wiki/Stem-and-leaf_plot" title="Stem-and-leaf plot">Stem-and-leaf plot</a>,
#  <a href="/wiki/Stern-Brocot_sequence" title="Stern-Brocot sequence">Stern-Brocot sequence</a>,
#  <a href="/wiki/String_append" title="String append">String append</a>,
#  <a href="/wiki/String_case" title="String case">String case</a>,
#  <a href="/wiki/String_comparison" title="String comparison">String comparison</a>,
#  <a href="/wiki/String_concatenation" title="String concatenation">String concatenation</a>,
#  <a href="/wiki/String_interpolation_(included)" title="String interpolation (included)">String interpolation (included)</a>,
#  <a href="/wiki/String_length" title="String length">String length</a>,
#  <a href="/wiki/String_matching" title="String matching">String matching</a>,
#  <a href="/wiki/String_prepend" title="String prepend">String prepend</a>,
#  <a href="/wiki/Strip_a_set_of_characters_from_a_string" title="Strip a set of characters from a string">Strip a set of characters from a string</a>,
#  <a href="/wiki/Strip_block_comments" title="Strip block comments">Strip block comments</a>,
#  <a href="/wiki/Strip_comments_from_a_string" title="Strip comments from a string">Strip comments from a string</a>,
#  <a href="/wiki/Strip_control_codes_and_extended_characters_from_a_string" title="Strip control codes and extended characters from a string">Strip control codes and extended characters from a string</a>,
#  <a href="/wiki/Strip_whitespace_from_a_string/Top_and_tail" title="Strip whitespace from a string/Top and tail">Strip whitespace from a string/Top and tail</a>,
#  <a href="/wiki/Subleq" title="Subleq">Subleq</a>,
#  <a href="/wiki/Substring" title="Substring">Substring</a>,
#  <a href="/wiki/Substring/Top_and_tail" title="Substring/Top and tail">Substring/Top and tail</a>,
#  <a href="/wiki/Subtractive_generator" title="Subtractive generator">Subtractive generator</a>,
#  <a href="/wiki/Sudoku" title="Sudoku">Sudoku</a>,
#  <a href="/wiki/Sum_and_product_of_an_array" title="Sum and product of an array">Sum and product of an array</a>,
#  <a href="/wiki/Sum_digits_of_an_integer" title="Sum digits of an integer">Sum digits of an integer</a>,
#  <a href="/wiki/Sum_multiples_of_3_and_5" title="Sum multiples of 3 and 5">Sum multiples of 3 and 5</a>,
#  <a href="/wiki/Sum_of_a_series" title="Sum of a series">Sum of a series</a>,
#  <a href="/wiki/Sum_of_squares" title="Sum of squares">Sum of squares</a>,
#  <a href="/wiki/Sutherland-Hodgman_polygon_clipping" title="Sutherland-Hodgman polygon clipping">Sutherland-Hodgman polygon clipping</a>,
#  <a href="/wiki/Symmetric_difference" title="Symmetric difference">Symmetric difference</a>,
#  <a href="/wiki/Synchronous_concurrency" title="Synchronous concurrency">Synchronous concurrency</a>,
#  <a href="/wiki/System_time" title="System time">System time</a>,
#  <a href="/wiki/Table_creation/Postal_addresses" title="Table creation/Postal addresses">Table creation/Postal addresses</a>,
#  <a href="/wiki/Take_notes_on_the_command_line" title="Take notes on the command line">Take notes on the command line</a>,
#  <a href="/wiki/Temperature_conversion" title="Temperature conversion">Temperature conversion</a>,
#  <a href="/wiki/Terminal_control/Clear_the_screen" title="Terminal control/Clear the screen">Terminal control/Clear the screen</a>,
#  <a href="/wiki/Terminal_control/Coloured_text" title="Terminal control/Coloured text">Terminal control/Coloured text</a>,
#  <a href="/wiki/Terminal_control/Cursor_movement" title="Terminal control/Cursor movement">Terminal control/Cursor movement</a>,
#  <a href="/wiki/Terminal_control/Cursor_positioning" title="Terminal control/Cursor positioning">Terminal control/Cursor positioning</a>,
#  <a href="/wiki/Terminal_control/Dimensions" title="Terminal control/Dimensions">Terminal control/Dimensions</a>,
#  <a href="/wiki/Terminal_control/Display_an_extended_character" title="Terminal control/Display an extended character">Terminal control/Display an extended character</a>,
#  <a href="/wiki/Terminal_control/Hiding_the_cursor" title="Terminal control/Hiding the cursor">Terminal control/Hiding the cursor</a>,
#  <a href="/wiki/Terminal_control/Inverse_video" title="Terminal control/Inverse video">Terminal control/Inverse video</a>,
#  <a href="/wiki/Terminal_control/Positional_read" title="Terminal control/Positional read">Terminal control/Positional read</a>,
#  <a href="/wiki/Terminal_control/Preserve_screen" title="Terminal control/Preserve screen">Terminal control/Preserve screen</a>,
#  <a href="/wiki/Terminal_control/Ringing_the_terminal_bell" title="Terminal control/Ringing the terminal bell">Terminal control/Ringing the terminal bell</a>,
#  <a href="/wiki/Terminal_control/Unicode_output" title="Terminal control/Unicode output">Terminal control/Unicode output</a>,
#  <a href="/wiki/Ternary_logic" title="Ternary logic">Ternary logic</a>,
#  <a href="/wiki/Test_a_function" title="Test a function">Test a function</a>,
#  <a href="/wiki/Text_processing/1" title="Text processing/1">Text processing/1</a>,
#  <a href="/wiki/Text_processing/2" title="Text processing/2">Text processing/2</a>,
#  <a href="/wiki/Text_processing/Max_licenses_in_use" title="Text processing/Max licenses in use">Text processing/Max licenses in use</a>,
#  <a href="/wiki/Textonyms" title="Textonyms">Textonyms</a>,
#  <a href="/wiki/The_ISAAC_Cipher" title="The ISAAC Cipher">The ISAAC Cipher</a>,
#  <a href="/wiki/The_Twelve_Days_of_Christmas" title="The Twelve Days of Christmas">The Twelve Days of Christmas</a>,
#  <a href="/wiki/Thiele%27s_interpolation_formula" title="Thiele's interpolation formula">Thiele's interpolation formula</a>,
#  <a href="/wiki/Tic-tac-toe" title="Tic-tac-toe">Tic-tac-toe</a>,
#  <a href="/wiki/Time_a_function" title="Time a function">Time a function</a>,
#  <a href="/wiki/Tokenize_a_string" title="Tokenize a string">Tokenize a string</a>,
#  <a href="/wiki/Top_rank_per_group" title="Top rank per group">Top rank per group</a>,
#  <a href="/wiki/Topic_variable" title="Topic variable">Topic variable</a>,
#  <a href="/wiki/Topological_sort" title="Topological sort">Topological sort</a>,
#  <a href="/wiki/Topswops" title="Topswops">Topswops</a>,
#  <a href="/wiki/Total_circles_area" title="Total circles area">Total circles area</a>,
#  <a href="/wiki/Towers_of_Hanoi" title="Towers of Hanoi">Towers of Hanoi</a>,
#  <a href="/wiki/Trabb_Pardo%E2%80%93Knuth_algorithm" title="Trabb Pardo–Knuth algorithm">Trabb Pardo–Knuth algorithm</a>,
#  <a href="/wiki/Tree_traversal" title="Tree traversal">Tree traversal</a>,
#  <a href="/wiki/Trigonometric_functions" title="Trigonometric functions">Trigonometric functions</a>,
#  <a href="/wiki/Truncatable_primes" title="Truncatable primes">Truncatable primes</a>,
#  <a href="/wiki/Truncate_a_file" title="Truncate a file">Truncate a file</a>,
#  <a href="/wiki/Twelve_statements" title="Twelve statements">Twelve statements</a>,
#  <a href="/wiki/Ulam_spiral_(for_primes)" title="Ulam spiral (for primes)">Ulam spiral (for primes)</a>,
#  <a href="/wiki/Unbias_a_random_generator" title="Unbias a random generator">Unbias a random generator</a>,
#  <a href="/wiki/Undefined_values" title="Undefined values">Undefined values</a>,
#  <a href="/wiki/Unicode_strings" title="Unicode strings">Unicode strings</a>,
#  <a href="/wiki/Unicode_variable_names" title="Unicode variable names">Unicode variable names</a>,
#  <a href="/wiki/Universal_Turing_machine" title="Universal Turing machine">Universal Turing machine</a>,
#  <a href="/wiki/Unix/ls" title="Unix/ls">Unix/ls</a>,
#  <a href="/wiki/Update_a_configuration_file" title="Update a configuration file">Update a configuration file</a>,
#  <a href="/wiki/URL_decoding" title="URL decoding">URL decoding</a>,
#  <a href="/wiki/URL_encoding" title="URL encoding">URL encoding</a>,
#  <a href="/wiki/Use_another_language_to_call_a_function" title="Use another language to call a function">Use another language to call a function</a>,
#  <a href="/wiki/User_input/Graphical" title="User input/Graphical">User input/Graphical</a>,
#  <a href="/wiki/User_input/Text" title="User input/Text">User input/Text</a>,
#  <a href="/wiki/Vampire_number" title="Vampire number">Vampire number</a>,
#  <a href="/wiki/Van_der_Corput_sequence" title="Van der Corput sequence">Van der Corput sequence</a>,
#  <a href="/wiki/Variable_size/Get" title="Variable size/Get">Variable size/Get</a>,
#  <a href="/wiki/Variable_size/Set" title="Variable size/Set">Variable size/Set</a>,
#  <a href="/wiki/Variable-length_quantity" title="Variable-length quantity">Variable-length quantity</a>,
#  <a href="/wiki/Variables" title="Variables">Variables</a>,
#  <a href="/wiki/Variadic_function" title="Variadic function">Variadic function</a>,
#  <a href="/wiki/Vector_products" title="Vector products">Vector products</a>,
#  <a href="/wiki/Verify_distribution_uniformity/Chi-squared_test" title="Verify distribution uniformity/Chi-squared test">Verify distribution uniformity/Chi-squared test</a>,
#  <a href="/wiki/Verify_distribution_uniformity/Naive" title="Verify distribution uniformity/Naive">Verify distribution uniformity/Naive</a>,
#  <a href="/wiki/Video_display_modes" title="Video display modes">Video display modes</a>,
#  <a href="/wiki/Vigen%C3%A8re_cipher" title="Vigenère cipher">Vigenère cipher</a>,
#  <a href="/wiki/Vigen%C3%A8re_cipher/Cryptanalysis" title="Vigenère cipher/Cryptanalysis">Vigenère cipher/Cryptanalysis</a>,
#  <a href="/wiki/Visualize_a_tree" title="Visualize a tree">Visualize a tree</a>,
#  <a href="/wiki/Vogel%27s_approximation_method" title="Vogel's approximation method">Vogel's approximation method</a>,
#  <a href="/wiki/Voronoi_diagram" title="Voronoi diagram">Voronoi diagram</a>,
#  <a href="/wiki/Walk_a_directory/Non-recursively" title="Walk a directory/Non-recursively">Walk a directory/Non-recursively</a>,
#  <a href="/wiki/Walk_a_directory/Recursively" title="Walk a directory/Recursively">Walk a directory/Recursively</a>,
#  <a href="/wiki/Web_scraping" title="Web scraping">Web scraping</a>,
#  <a href="/wiki/Window_creation" title="Window creation">Window creation</a>,
#  <a href="/wiki/Window_creation/X11" title="Window creation/X11">Window creation/X11</a>,
#  <a href="/wiki/Window_management" title="Window management">Window management</a>,
#  <a href="/wiki/Wireworld" title="Wireworld">Wireworld</a>,
#  <a href="/wiki/Word_wrap" title="Word wrap">Word wrap</a>,
#  <a href="/wiki/World_Cup_group_stage" title="World Cup group stage">World Cup group stage</a>,
#  <a href="/wiki/Write_float_arrays_to_a_text_file" title="Write float arrays to a text file">Write float arrays to a text file</a>,
#  <a href="/wiki/Write_language_name_in_3D_ASCII" title="Write language name in 3D ASCII">Write language name in 3D ASCII</a>,
#  <a href="/wiki/Write_to_Windows_event_log" title="Write to Windows event log">Write to Windows event log</a>,
#  <a href="/wiki/Xiaolin_Wu%27s_line_algorithm" title="Xiaolin Wu's line algorithm">Xiaolin Wu's line algorithm</a>,
#  <a href="/wiki/XML/DOM_serialization" title="XML/DOM serialization">XML/DOM serialization</a>,
#  <a href="/wiki/XML/Input" title="XML/Input">XML/Input</a>,
#  <a href="/wiki/XML/Output" title="XML/Output">XML/Output</a>,
#  <a href="/wiki/XML/XPath" title="XML/XPath">XML/XPath</a>,
#  <a href="/wiki/Y_combinator" title="Y combinator">Y combinator</a>,
#  <a href="/wiki/Yahoo!_search_interface" title="Yahoo! search interface">Yahoo! search interface</a>,
#  <a href="/wiki/Yin_and_yang" title="Yin and yang">Yin and yang</a>,
#  <a href="/wiki/Zebra_puzzle" title="Zebra puzzle">Zebra puzzle</a>,
#  <a href="/wiki/Zeckendorf_arithmetic" title="Zeckendorf arithmetic">Zeckendorf arithmetic</a>,
#  <a href="/wiki/Zeckendorf_number_representation" title="Zeckendorf number representation">Zeckendorf number representation</a>,
#  <a href="/wiki/Zero_to_the_zero_power" title="Zero to the zero power">Zero to the zero power</a>,
#  <a href="/wiki/Zhang-Suen_thinning_algorithm" title="Zhang-Suen thinning algorithm">Zhang-Suen thinning algorithm</a>,
#  <a href="/wiki/Zig-zag_matrix" title="Zig-zag matrix">Zig-zag matrix</a>,
#  <a href="http://rosettacode.org/mw/index.php?title=Category:Programming_Tasks&amp;oldid=165935">http://rosettacode.org/mw/index.php?title=Category:Programming_Tasks&amp;oldid=165935</a>,
#  <a href="/mw/index.php?title=Special:UserLogin&amp;returnto=Category%3AProgramming+Tasks&amp;type=signup">Create account</a>,
#  <a accesskey="o" href="/mw/index.php?title=Special:UserLogin&amp;returnto=Category%3AProgramming+Tasks" title="You are encouraged to log in; however, it is not mandatory [o]">Log in</a>,
#  <a accesskey="c" href="/wiki/Category:Programming_Tasks" title="View the category page [c]">Category</a>,
#  <a accesskey="t" href="/wiki/Category_talk:Programming_Tasks" title="Discussion about the content page [t]">Discussion</a>,
#  <a href="#"></a>,
#  <a href="/wiki/Category:Programming_Tasks">Read</a>,
#  <a accesskey="e" href="/mw/index.php?title=Category:Programming_Tasks&amp;action=edit" title="You can edit this page. Please use the preview button before saving [e]">Edit</a>,
#  <a accesskey="h" href="/mw/index.php?title=Category:Programming_Tasks&amp;action=history" title="Past revisions of this page [h]">View history</a>,
#  <a href="#"></a>,
#  <a href="/wiki/Rosetta_Code" style="background-image: url(/mw/title.png);" title="Visit the main page"></a>,
#  <a href="http://twitter.com/rosettacode" rel="nofollow">Twitter</a>,
#  <a href="/wiki/Special:WebChat">Chat/IRC</a>,
#  <a href="http://rosettacode.org/planet" rel="nofollow">Planet</a>,
#  <a href="/wiki/Rosetta_Code:Village_Pump">The Village Pump</a>,
#  <a href="/wiki/Rosetta_Code:Finances">Finances</a>,
#  <a href="/wiki/Category:Programming_Languages">Languages</a>,
#  <a href="/wiki/Category:Programming_Tasks">Tasks</a>,
#  <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]">Recent changes</a>,
#  <a href="/wiki/Help:Similar_Sites">Similar sites</a>,
#  <a accesskey="x" href="/wiki/Special:Random" title="Load a random page [x]">Random page</a>,
#  <a class="twitter-share-button" data-hashtags="rosettacode" data-lang="en" data-size="large" href="https://twitter.com/share">Tweet</a>,
#  <a accesskey="j" href="/wiki/Special:WhatLinksHere/Category:Programming_Tasks" title="A list of all wiki pages that link here [j]">What links here</a>,
#  <a accesskey="k" href="/wiki/Special:RecentChangesLinked/Category:Programming_Tasks" title="Recent changes in pages linked from this page [k]">Related changes</a>,
#  <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">Special pages</a>,
#  <a accesskey="p" href="/mw/index.php?title=Category:Programming_Tasks&amp;printable=yes" rel="alternate" title="Printable version of this page [p]">Printable version</a>,
#  <a href="/mw/index.php?title=Category:Programming_Tasks&amp;oldid=165935" title="Permanent link to this revision of the page">Permanent link</a>,
#  <a href="/wiki/Special:Browse/Category:Programming_Tasks" title="Special:Browse/Category:Programming Tasks">Browse properties</a>,
#  <a class="external" href="http://www.gnu.org/licenses/fdl-1.2.html">GNU Free Documentation License 1.2</a>,
#  <a href="/wiki/Rosetta_Code:Privacy_policy" title="Rosetta Code:Privacy policy">Privacy policy</a>,
#  <a href="/wiki/Rosetta_Code:About" title="Rosetta Code:About">About Rosetta Code</a>,
#  <a href="/wiki/Rosetta_Code:General_disclaimer" title="Rosetta Code:General disclaimer">Disclaimers</a>,
#  <a href="http://www.gnu.org/licenses/fdl-1.2.html"><img alt="GNU Free Documentation License 1.2" height="31" src="/mw/skins/common/images/gnu-fdl.png" width="88"/></a>,
#  <a href="//www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" src="/mw/skins/common/images/poweredby_mediawiki_88x31.png" width="88"/></a>,
#  <a href="http://www.semantic-mediawiki.org/wiki/Semantic_MediaWiki"><img alt="Powered by Semantic MediaWiki" height="31" src="/mw/extensions/SemanticMediaWiki/skins/images/smw_button.png" width="88"/></a>]

# %%
def scrape_links():
   req = urllib.request.Request('http://rosettacode.org/wiki/Category:Programming_Tasks', headers={'User-Agent': 'Mozilla/5.0'})
   content = urllib.request.urlopen(req).read()
   soup = BeautifulSoup(content)
   link_list = [link.get('href') for link in soup.find_all('a')]
   return [link for link in link_list[1:] if link.startswith('/wiki/')]
scrape_links()
# Out:
# ['/wiki/Rosetta_Code:Add_a_Task',
#  '/wiki/Category_talk:Programming_Tasks',
#  '/wiki/100_doors',
#  '/wiki/24_game',
#  '/wiki/24_game/Solve',
#  '/wiki/9_billion_names_of_God_the_integer',
#  '/wiki/99_Bottles_of_Beer',
#  '/wiki/A%2BB',
#  '/wiki/ABC_Problem',
#  '/wiki/Abstract_type',
#  '/wiki/Abundant,_deficient_and_perfect_number_classifications',
#  '/wiki/Accumulator_factory',
#  '/wiki/Ackermann_function',
#  '/wiki/Active_Directory/Connect',
#  '/wiki/Active_Directory/Search_for_a_user',
#  '/wiki/Active_object',
#  '/wiki/Add_a_variable_to_a_class_instance_at_runtime',
#  '/wiki/Address_of_a_variable',
#  '/wiki/AKS_test_for_primes',
#  '/wiki/Align_columns',
#  '/wiki/Aliquot_sequence_classifications',
#  '/wiki/Almost_prime',
#  '/wiki/Amb',
#  '/wiki/Amicable_pairs',
#  '/wiki/Anagrams',
#  '/wiki/Anagrams/Deranged_anagrams',
#  '/wiki/Animate_a_pendulum',
#  '/wiki/Animation',
#  '/wiki/Anonymous_recursion',
#  '/wiki/Append_a_record_to_the_end_of_a_text_file',
#  '/wiki/Apply_a_callback_to_an_array',
#  '/wiki/Arbitrary-precision_integers_(included)',
#  '/wiki/Arena_storage_pool',
#  '/wiki/Arithmetic_evaluation',
#  '/wiki/Arithmetic-geometric_mean',
#  '/wiki/Arithmetic-geometric_mean/Calculate_Pi',
#  '/wiki/Arithmetic/Complex',
#  '/wiki/Arithmetic/Integer',
#  '/wiki/Arithmetic/Rational',
#  '/wiki/Array_concatenation',
#  '/wiki/Arrays',
#  '/wiki/Assertions',
#  '/wiki/Associative_array/Creation',
#  '/wiki/Associative_array/Iteration',
#  '/wiki/Atomic_updates',
#  '/wiki/Average_loop_length',
#  '/wiki/Averages/Arithmetic_mean',
#  '/wiki/Averages/Mean_angle',
#  '/wiki/Averages/Mean_time_of_day',
#  '/wiki/Averages/Median',
#  '/wiki/Averages/Mode',
#  '/wiki/Averages/Pythagorean_means',
#  '/wiki/Averages/Root_mean_square',
#  '/wiki/Averages/Simple_moving_average',
#  '/wiki/Balanced_brackets',
#  '/wiki/Balanced_ternary',
#  '/wiki/Benford%27s_law',
#  '/wiki/Bernoulli_numbers',
#  '/wiki/Best_shuffle',
#  '/wiki/Binary_digits',
#  '/wiki/Binary_search',
#  '/wiki/Binary_strings',
#  '/wiki/Bitcoin/address_validation',
#  '/wiki/Bitcoin/public_point_to_address',
#  '/wiki/Bitmap',
#  '/wiki/Bitmap/Bresenham%27s_line_algorithm',
#  '/wiki/Bitmap/B%C3%A9zier_curves/Cubic',
#  '/wiki/Bitmap/B%C3%A9zier_curves/Quadratic',
#  '/wiki/Bitmap/Flood_fill',
#  '/wiki/Bitmap/Histogram',
#  '/wiki/Bitmap/Midpoint_circle_algorithm',
#  '/wiki/Bitmap/PPM_conversion_through_a_pipe',
#  '/wiki/Bitmap/Read_a_PPM_file',
#  '/wiki/Bitmap/Read_an_image_through_a_pipe',
#  '/wiki/Bitmap/Write_a_PPM_file',
#  '/wiki/Bitwise_IO',
#  '/wiki/Bitwise_operations',
#  '/wiki/Boolean_values',
#  '/wiki/Box_the_compass',
#  '/wiki/Break_OO_privacy',
#  '/wiki/Brownian_tree',
#  '/wiki/Bulls_and_cows',
#  '/wiki/Bulls_and_cows/Player',
#  '/wiki/Caesar_cipher',
#  '/wiki/Calendar',
#  '/wiki/Calendar_-_for_%22REAL%22_programmers',
#  '/wiki/Call_a_foreign-language_function',
#  '/wiki/Call_a_function',
#  '/wiki/Call_a_function_in_a_shared_library',
#  '/wiki/Call_an_object_method',
#  '/wiki/Canny_edge_detector',
#  '/wiki/Carmichael_3_strong_pseudoprimes',
#  '/wiki/Case-sensitivity_of_identifiers',
#  '/wiki/Casting_out_nines',
#  '/wiki/Catalan_numbers',
#  '/wiki/Catalan_numbers/Pascal%27s_triangle',
#  '/wiki/Catamorphism',
#  '/wiki/Catmull%E2%80%93Clark_subdivision_surface',
#  '/wiki/Character_codes',
#  '/wiki/Chat_server',
#  '/wiki/Check_Machin-like_formulas',
#  '/wiki/Check_that_file_exists',
#  '/wiki/Checkpoint_synchronization',
#  '/wiki/Chinese_remainder_theorem',
#  '/wiki/Cholesky_decomposition',
#  '/wiki/Circles_of_given_radius_through_two_points',
#  '/wiki/Classes',
#  '/wiki/Closest-pair_problem',
#  '/wiki/Closures/Value_capture',
#  '/wiki/Collections',
#  '/wiki/Color_of_a_screen_pixel',
#  '/wiki/Color_quantization',
#  '/wiki/Colour_bars/Display',
#  '/wiki/Colour_pinstripe/Display',
#  '/wiki/Colour_pinstripe/Printer',
#  '/wiki/Combinations',
#  '/wiki/Combinations_and_permutations',
#  '/wiki/Combinations_with_repetitions',
#  '/wiki/Comma_quibbling',
#  '/wiki/Command-line_arguments',
#  '/wiki/Comments',
#  '/wiki/Compare_sorting_algorithms%27_performance',
#  '/wiki/Compile-time_calculation',
#  '/wiki/Compound_data_type',
#  '/wiki/Concurrent_computing',
#  '/wiki/Conditional_structures',
#  '/wiki/Conjugate_transpose',
#  '/wiki/Constrained_genericity',
#  '/wiki/Constrained_random_points_on_a_circle',
#  '/wiki/Continued_fraction',
#  '/wiki/Continued_fraction/Arithmetic/Construct_from_rational_number',
#  '/wiki/Continued_fraction/Arithmetic/G(matrix_NG,_Contined_Fraction_N)',
#  '/wiki/Continued_fraction/Arithmetic/G(matrix_NG,_Contined_Fraction_N1,_Contined_Fraction_N2)',
#  '/wiki/Convert_decimal_number_to_rational',
#  '/wiki/Conway%27s_Game_of_Life',
#  '/wiki/Copy_a_string',
#  '/wiki/Count_in_factors',
#  '/wiki/Count_in_octal',
#  '/wiki/Count_occurrences_of_a_substring',
#  '/wiki/Count_the_coins',
#  '/wiki/CRC-32',
#  '/wiki/Create_a_file',
#  '/wiki/Create_a_file_on_magnetic_tape',
#  '/wiki/Create_a_two-dimensional_array_at_runtime',
#  '/wiki/Create_an_HTML_table',
#  '/wiki/Create_an_object_at_a_given_address',
#  '/wiki/CSV_data_manipulation',
#  '/wiki/CSV_to_HTML_translation',
#  '/wiki/Currying',
#  '/wiki/Cut_a_rectangle',
#  '/wiki/Date_format',
#  '/wiki/Date_manipulation',
#  '/wiki/Day_of_the_week',
#  '/wiki/Deal_cards_for_FreeCell',
#  '/wiki/Death_Star',
#  '/wiki/Deconvolution/1D',
#  '/wiki/Deconvolution/2D%2B',
#  '/wiki/Deepcopy',
#  '/wiki/Define_a_primitive_data_type',
#  '/wiki/Delegates',
#  '/wiki/Delete_a_file',
#  '/wiki/Detect_division_by_zero',
#  '/wiki/Determine_if_a_string_is_numeric',
#  '/wiki/Determine_if_only_one_instance_is_running',
#  '/wiki/Digital_root',
#  '/wiki/Digital_root/Multiplicative_digital_root',
#  '/wiki/Dinesman%27s_multiple-dwelling_problem',
#  '/wiki/Dining_philosophers',
#  '/wiki/Discordian_date',
#  '/wiki/Distributed_programming',
#  '/wiki/DNS_query',
#  '/wiki/Documentation',
#  '/wiki/Dot_product',
#  '/wiki/Doubly-linked_list/Definition',
#  '/wiki/Doubly-linked_list/Element_definition',
#  '/wiki/Doubly-linked_list/Element_insertion',
#  '/wiki/Doubly-linked_list/Traversal',
#  '/wiki/Dragon_curve',
#  '/wiki/Draw_a_clock',
#  '/wiki/Draw_a_cuboid',
#  '/wiki/Draw_a_sphere',
#  '/wiki/Dutch_national_flag_problem',
#  '/wiki/Dynamic_variable_names',
#  '/wiki/Echo_server',
#  '/wiki/Element-wise_operations',
#  '/wiki/Empty_directory',
#  '/wiki/Empty_program',
#  '/wiki/Empty_string',
#  '/wiki/Enforced_immutability',
#  '/wiki/Entropy',
#  '/wiki/Enumerations',
#  '/wiki/Environment_variables',
#  '/wiki/Equilibrium_index',
#  '/wiki/Ethiopian_multiplication',
#  '/wiki/Euler_method',
#  '/wiki/Euler%27s_sum_of_powers_conjecture',
#  '/wiki/Evaluate_binomial_coefficients',
#  '/wiki/Even_or_odd',
#  '/wiki/Events',
#  '/wiki/Evolutionary_algorithm',
#  '/wiki/Exceptions',
#  '/wiki/Exceptions/Catch_an_exception_thrown_in_a_nested_call',
#  '/wiki/Executable_library',
#  '/wiki/Execute_a_Markov_algorithm',
#  '/wiki/Execute_a_system_command',
#  '/wiki/Execute_Brain****',
#  '/wiki/Execute_HQ9%2B',
#  '/wiki/Execute_SNUSP',
#  '/wiki/Exponentiation_operator',
#  '/wiki/Extend_your_language',
#  '/wiki/Extensible_prime_generator',
#  '/wiki/Extreme_floating_point_values',
#  '/wiki/Factorial',
#  '/wiki/Factors_of_a_Mersenne_number',
#  '/wiki/Factors_of_an_integer',
#  '/wiki/Fast_Fourier_transform',
#  '/wiki/Fibonacci_n-step_number_sequences',
#  '/wiki/Fibonacci_sequence',
#  '/wiki/Fibonacci_word',
#  '/wiki/Fibonacci_word/fractal',
#  '/wiki/File_input/output',
#  '/wiki/File_modification_time',
#  '/wiki/File_size',
#  '/wiki/Filter',
#  '/wiki/Find_common_directory_path',
#  '/wiki/Find_largest_left_truncatable_prime_in_a_given_base',
#  '/wiki/Find_limit_of_recursion',
#  '/wiki/Find_the_last_Sunday_of_each_month',
#  '/wiki/Find_the_missing_permutation',
#  '/wiki/First_class_environments',
#  '/wiki/First-class_functions',
#  '/wiki/First-class_functions/Use_numbers_analogously',
#  '/wiki/Five_weekends',
#  '/wiki/FizzBuzz',
#  '/wiki/Flatten_a_list',
#  '/wiki/Flipping_bits_game',
#  '/wiki/Flow-control_structures',
#  '/wiki/Floyd%27s_triangle',
#  '/wiki/Forest_fire',
#  '/wiki/Fork',
#  '/wiki/Formal_power_series',
#  '/wiki/Formatted_numeric_output',
#  '/wiki/Forward_difference',
#  '/wiki/Four_bit_adder',
#  '/wiki/Fractal_tree',
#  '/wiki/Fractran',
#  '/wiki/Function_composition',
#  '/wiki/Function_definition',
#  '/wiki/Function_frequency',
#  '/wiki/Function_prototype',
#  '/wiki/Galton_box_animation',
#  '/wiki/Gamma_function',
#  '/wiki/Gaussian_elimination',
#  '/wiki/Generate_Chess960_starting_position',
#  '/wiki/Generate_lower_case_ASCII_alphabet',
#  '/wiki/Generator/Exponential',
#  '/wiki/Generic_swap',
#  '/wiki/Globally_replace_text_in_several_files',
#  '/wiki/Go_Fish',
#  '/wiki/Gray_code',
#  '/wiki/Grayscale_image',
#  '/wiki/Greatest_common_divisor',
#  '/wiki/Greatest_element_of_a_list',
#  '/wiki/Greatest_subsequential_sum',
#  '/wiki/Greyscale_bars/Display',
#  '/wiki/Guess_the_number',
#  '/wiki/Guess_the_number/With_feedback',
#  '/wiki/Guess_the_number/With_feedback_(player)',
#  '/wiki/GUI_component_interaction',
#  '/wiki/GUI_enabling/disabling_of_controls',
#  '/wiki/GUI/Maximum_window_dimensions',
#  '/wiki/Hailstone_sequence',
#  '/wiki/Hamming_numbers',
#  '/wiki/Handle_a_signal',
#  '/wiki/Happy_numbers',
#  '/wiki/Harshad_or_Niven_series',
#  '/wiki/Hash_from_two_arrays',
#  '/wiki/Hash_join',
#  '/wiki/Haversine_formula',
#  '/wiki/Hello_world/Graphical',
#  '/wiki/Hello_world/Line_printer',
#  '/wiki/Hello_world/Newbie',
#  '/wiki/Hello_world/Newline_omission',
#  '/wiki/Hello_world/Standard_error',
#  '/wiki/Hello_world/Text',
#  '/wiki/Hello_world/Web_server',
#  '/wiki/Here_document',
#  '/wiki/Heronian_triangles',
#  '/wiki/Hickerson_series_of_almost_integers',
#  '/wiki/Higher-order_functions',
#  '/wiki/History_variables',
#  '/wiki/Hofstadter_Figure-Figure_sequences',
#  '/wiki/Hofstadter_Q_sequence',
#  '/wiki/Hofstadter-Conway_$10,000_sequence',
#  '/wiki/Holidays_related_to_Easter',
#  '/wiki/Honeycombs',
#  '/wiki/Horizontal_sundial_calculations',
#  '/wiki/Horner%27s_rule_for_polynomial_evaluation',
#  '/wiki/Host_introspection',
#  '/wiki/Hostname',
#  '/wiki/Hough_transform',
#  '/wiki/HTTP',
#  '/wiki/HTTPS',
#  '/wiki/HTTPS/Authenticated',
#  '/wiki/HTTPS/Client-authenticated',
#  '/wiki/Huffman_coding',
#  '/wiki/I_before_E_except_after_C',
#  '/wiki/IBAN',
#  '/wiki/Identity_matrix',
#  '/wiki/Image_convolution',
#  '/wiki/Image_noise',
#  '/wiki/Include_a_file',
#  '/wiki/Increment_a_numerical_string',
#  '/wiki/Infinity',
#  '/wiki/Inheritance/Multiple',
#  '/wiki/Inheritance/Single',
#  '/wiki/Input_loop',
#  '/wiki/Integer_comparison',
#  '/wiki/Integer_overflow',
#  '/wiki/Integer_sequence',
#  '/wiki/Interactive_programming',
#  '/wiki/Introspection',
#  '/wiki/Inverted_index',
#  '/wiki/Inverted_syntax',
#  '/wiki/Iterated_digits_squaring',
#  '/wiki/Jensen%27s_Device',
#  '/wiki/JortSort',
#  '/wiki/Josephus_problem',
#  '/wiki/Joystick_position',
#  '/wiki/JSON',
#  '/wiki/Jump_anywhere',
#  '/wiki/K-d_tree',
#  '/wiki/K-means%2B%2B_clustering',
#  '/wiki/Kaprekar_numbers',
#  '/wiki/Keyboard_input/Flush_the_keyboard_buffer',
#  '/wiki/Keyboard_input/Keypress_check',
#  '/wiki/Keyboard_input/Obtain_a_Y_or_N_response',
#  '/wiki/Keyboard_macros',
#  '/wiki/Knapsack_problem/0-1',
#  '/wiki/Knapsack_problem/Bounded',
#  '/wiki/Knapsack_problem/Continuous',
#  '/wiki/Knapsack_problem/Unbounded',
#  '/wiki/Knight%27s_tour',
#  '/wiki/Knuth_shuffle',
#  '/wiki/Knuth%27s_algorithm_S',
#  '/wiki/Langton%27s_ant',
#  '/wiki/Largest_int_from_concatenated_ints',
#  '/wiki/Last_Friday_of_each_month',
#  '/wiki/Last_letter-first_letter',
#  '/wiki/Leap_year',
#  '/wiki/Least_common_multiple',
#  '/wiki/Left_factorials',
#  '/wiki/Letter_frequency',
#  '/wiki/Levenshtein_distance',
#  '/wiki/Linear_congruential_generator',
#  '/wiki/List_comprehensions',
#  '/wiki/Literals/Floating_point',
#  '/wiki/Literals/Integer',
#  '/wiki/Literals/String',
#  '/wiki/Logical_operations',
#  '/wiki/Long_multiplication',
#  '/wiki/Longest_common_subsequence',
#  '/wiki/Longest_increasing_subsequence',
#  '/wiki/Longest_string_challenge',
#  '/wiki/Look-and-say_sequence',
#  '/wiki/Loop_over_multiple_arrays_simultaneously',
#  '/wiki/Loops/Break',
#  '/wiki/Loops/Continue',
#  '/wiki/Loops/Do-while',
#  '/wiki/Loops/Downward_for',
#  '/wiki/Loops/For',
#  '/wiki/Loops/For_with_a_specified_step',
#  '/wiki/Loops/Foreach',
#  '/wiki/Loops/Infinite',
#  '/wiki/Loops/N_plus_one_half',
#  '/wiki/Loops/Nested',
#  '/wiki/Loops/While',
#  '/wiki/LU_decomposition',
#  '/wiki/Lucas-Lehmer_test',
#  '/wiki/Ludic_numbers',
#  '/wiki/Luhn_test_of_credit_card_numbers',
#  '/wiki/LZW_compression',
#  '/wiki/Machine_code',
#  '/wiki/Mad_Libs',
#  '/wiki/Magic_squares_of_odd_order',
#  '/wiki/Main_step_of_GOST_28147-89',
#  '/wiki/Make_directory_path',
#  '/wiki/Man_or_boy_test',
#  '/wiki/Mandelbrot_set',
#  '/wiki/Map_range',
#  '/wiki/Matrix_arithmetic',
#  '/wiki/Matrix_multiplication',
#  '/wiki/Matrix_transposition',
#  '/wiki/Matrix-exponentiation_operator',
#  '/wiki/Maximum_triangle_path_sum',
#  '/wiki/Maze_generation',
#  '/wiki/Maze_solving',
#  '/wiki/MD4',
#  '/wiki/MD5',
#  '/wiki/MD5/Implementation',
#  '/wiki/Median_filter',
#  '/wiki/Memory_allocation',
#  '/wiki/Memory_layout_of_a_data_structure',
#  '/wiki/Menu',
#  '/wiki/Metaprogramming',
#  '/wiki/Metered_concurrency',
#  '/wiki/Metronome',
#  '/wiki/Middle_three_digits',
#  '/wiki/Miller-Rabin_primality_test',
#  '/wiki/Minesweeper_game',
#  '/wiki/Modular_exponentiation',
#  '/wiki/Modular_inverse',
#  '/wiki/Monte_Carlo_methods',
#  '/wiki/Monty_Hall_problem',
#  '/wiki/Morse_code',
#  '/wiki/Mouse_position',
#  '/wiki/Move-to-front_algorithm',
#  '/wiki/Multifactorial',
#  '/wiki/Multiple_distinct_objects',
#  '/wiki/Multiple_regression',
#  '/wiki/Multiplication_tables',
#  '/wiki/Multiplicative_order',
#  '/wiki/Multisplit',
#  '/wiki/Munching_squares',
#  '/wiki/Mutual_recursion',
#  '/wiki/N%27th',
#  '/wiki/N-queens_problem',
#  '/wiki/Named_parameters',
#  '/wiki/Narcissist',
#  '/wiki/Narcissistic_decimal_number',
#  '/wiki/Natural_sorting',
#  '/wiki/Nautical_bell',
#  '/wiki/Non-continuous_subsequences',
#  '/wiki/Non-decimal_radices/Convert',
#  '/wiki/Non-decimal_radices/Input',
#  '/wiki/Non-decimal_radices/Output',
#  '/wiki/Nth_root',
#  '/wiki/Null_object',
#  '/wiki/Number_names',
#  '/wiki/Number_reversal_game',
#  '/wiki/Numeric_error_propagation',
#  '/wiki/Numerical_integration',
#  '/wiki/Numerical_integration/Gauss-Legendre_Quadrature',
#  '/wiki/Object_serialization',
#  '/wiki/Odd_word_problem',
#  '/wiki/Old_lady_swallowed_a_fly',
#  '/wiki/OLE_Automation',
#  '/wiki/One_of_n_lines_in_a_file',
#  '/wiki/One-dimensional_cellular_automata',
#  '/wiki/OpenGL',
#  '/wiki/Operator_precedence',
#  '/wiki/Optional_parameters',
#  '/wiki/Order_disjoint_list_items',
#  '/wiki/Order_two_numerical_lists',
#  '/wiki/Ordered_Partitions',
#  '/wiki/Ordered_words',
#  '/wiki/Palindrome_detection',
#  '/wiki/Pangram_checker',
#  '/wiki/Paraffins',
#  '/wiki/Parallel_calculations',
#  '/wiki/Parametric_polymorphism',
#  '/wiki/Parametrized_SQL_statement',
#  '/wiki/Parse_an_IP_Address',
#  '/wiki/Parsing/RPN_calculator_algorithm',
#  '/wiki/Parsing/RPN_to_infix_conversion',
#  '/wiki/Parsing/Shunting-yard_algorithm',
#  '/wiki/Partial_function_application',
#  '/wiki/Pascal_matrix_generation',
#  '/wiki/Pascal%27s_triangle',
#  '/wiki/Pascal%27s_triangle/Puzzle',
#  '/wiki/Pattern_matching',
#  '/wiki/Penney%27s_game',
#  '/wiki/Percentage_difference_between_images',
#  '/wiki/Percolation/Bond_percolation',
#  '/wiki/Percolation/Mean_cluster_density',
#  '/wiki/Percolation/Mean_run_density',
#  '/wiki/Percolation/Site_percolation',
#  '/wiki/Perfect_numbers',
#  '/wiki/Permutation_test',
#  '/wiki/Permutations',
#  '/wiki/Permutations_by_swapping',
#  '/wiki/Permutations/Derangements',
#  '/wiki/Permutations/Rank_of_a_permutation',
#  '/wiki/Pernicious_numbers',
#  '/wiki/Phrase_reversals',
#  '/wiki/Pi',
#  '/wiki/Pick_random_element',
#  '/wiki/Pig_the_dice_game',
#  '/wiki/Pig_the_dice_game/Player',
#  '/wiki/Pinstripe/Display',
#  '/wiki/Pinstripe/Printer',
#  '/wiki/Play_recorded_sounds',
#  '/wiki/Playing_cards',
#  '/wiki/Plot_coordinate_pairs',
#  '/wiki/Pointers_and_references',
#  '/wiki/Polymorphic_copy',
#  '/wiki/Polymorphism',
#  '/wiki/Polynomial_long_division',
#  '/wiki/Polynomial_regression',
#  '/wiki/Power_set',
#  '/wiki/Pragmatic_directives',
#  '/wiki/Price_fraction',
#  '/wiki/Primality_by_trial_division',
#  '/wiki/Prime_decomposition',
#  '/wiki/Primes_-_allocate_descendants_to_their_ancestors',
#  '/wiki/Priority_queue',
#  '/wiki/Probabilistic_choice',
#  '/wiki/Problem_of_Apollonius',
#  '/wiki/Program_name',
#  '/wiki/Program_termination',
#  '/wiki/Pythagorean_triples',
#  '/wiki/QR_decomposition',
#  '/wiki/Quaternion_type',
#  '/wiki/Queue/Definition',
#  '/wiki/Queue/Usage',
#  '/wiki/Quickselect_algorithm',
#  '/wiki/Quine',
#  '/wiki/Random_number_generator_(device)',
#  '/wiki/Random_number_generator_(included)',
#  '/wiki/Random_numbers',
#  '/wiki/Range_expansion',
#  '/wiki/Range_extraction',
#  '/wiki/Ranking_methods',
#  '/wiki/Rate_counter',
#  '/wiki/Ray-casting_algorithm',
#  '/wiki/RCRPG',
#  '/wiki/Read_a_configuration_file',
#  '/wiki/Read_a_file_line_by_line',
#  '/wiki/Read_a_specific_line_from_a_file',
#  '/wiki/Read_entire_file',
#  '/wiki/Real_constants_and_functions',
#  '/wiki/Record_sound',
#  '/wiki/Reduced_row_echelon_form',
#  '/wiki/Regular_expressions',
#  '/wiki/Remove_duplicate_elements',
#  '/wiki/Remove_lines_from_a_file',
#  '/wiki/Rename_a_file',
#  '/wiki/Rendezvous',
#  '/wiki/Rep-string',
#  '/wiki/Repeat_a_string',
#  '/wiki/Resistor_mesh',
#  '/wiki/Respond_to_an_unknown_method_call',
#  '/wiki/Return_multiple_values',
#  '/wiki/Reverse_a_string',
#  '/wiki/Reverse_words_in_a_string',
#  '/wiki/RIPEMD-160',
#  '/wiki/Rock-paper-scissors',
#  '/wiki/Roman_numerals/Decode',
#  '/wiki/Roman_numerals/Encode',
#  '/wiki/Roots_of_a_function',
#  '/wiki/Roots_of_a_quadratic_function',
#  '/wiki/Roots_of_unity',
#  '/wiki/Rosetta_Code/Count_examples',
#  '/wiki/Rosetta_Code/Find_bare_lang_tags',
#  '/wiki/Rosetta_Code/Find_unimplemented_tasks',
#  '/wiki/Rosetta_Code/Fix_code_tags',
#  '/wiki/Rosetta_Code/Rank_languages_by_popularity',
#  '/wiki/Rot-13',
#  '/wiki/RSA_code',
#  '/wiki/Run-length_encoding',
#  '/wiki/Runge-Kutta_method',
#  '/wiki/Runtime_evaluation',
#  '/wiki/Runtime_evaluation/In_an_environment',
#  '/wiki/S-Expressions',
#  '/wiki/Safe_addition',
#  '/wiki/Sailors,_coconuts_and_a_monkey_problem',
#  '/wiki/Same_Fringe',
#  '/wiki/Scope_modifiers',
#  '/wiki/Scope/Function_names_and_labels',
#  '/wiki/Search_a_list',
#  '/wiki/Secure_temporary_file',
#  '/wiki/SEDOLs',
#  '/wiki/Self-describing_numbers',
#  '/wiki/Self-referential_sequence',
#  '/wiki/Semiprime',
#  '/wiki/Semordnilap',
#  '/wiki/Send_an_unknown_method_call',
#  '/wiki/Send_email',
#  '/wiki/Sequence_of_non-squares',
#  '/wiki/Sequence_of_primes_by_Trial_Division',
#  '/wiki/Set',
#  '/wiki/Set_consolidation',
#  '/wiki/Set_of_real_numbers',
#  '/wiki/Set_puzzle',
#  '/wiki/Seven-sided_dice_from_five-sided_dice',
#  '/wiki/SHA-1',
#  '/wiki/SHA-256',
#  '/wiki/Shell_one-liner',
#  '/wiki/Short-circuit_evaluation',
#  '/wiki/Show_the_epoch',
#  '/wiki/Sierpinski_carpet',
#  '/wiki/Sierpinski_triangle',
#  '/wiki/Sierpinski_triangle/Graphical',
#  '/wiki/Sieve_of_Eratosthenes',
#  '/wiki/Simple_database',
#  '/wiki/Simple_windowed_application',
#  '/wiki/Simulate_input/Keyboard',
#  '/wiki/Simulate_input/Mouse',
#  '/wiki/Singleton',
#  '/wiki/Singly-linked_list/Element_definition',
#  '/wiki/Singly-linked_list/Element_insertion',
#  '/wiki/Singly-linked_list/Traversal',
#  '/wiki/Sleep',
#  '/wiki/SOAP',
#  '/wiki/Sockets',
#  '/wiki/Sokoban',
#  '/wiki/Solve_a_Hidato_puzzle',
#  '/wiki/Solve_a_Holy_Knight%27s_tour',
#  '/wiki/Solve_a_Hopido_puzzle',
#  '/wiki/Solve_a_Numbrix_puzzle',
#  '/wiki/Solve_the_no_connection_puzzle',
#  '/wiki/Sort_an_array_of_composite_structures',
#  '/wiki/Sort_an_integer_array',
#  '/wiki/Sort_disjoint_sublist',
#  '/wiki/Sort_stability',
#  '/wiki/Sort_using_a_custom_comparator',
#  '/wiki/Sorting_algorithms/Bead_sort',
#  '/wiki/Sorting_algorithms/Bogosort',
#  '/wiki/Sorting_algorithms/Bubble_sort',
#  '/wiki/Sorting_algorithms/Cocktail_sort',
#  '/wiki/Sorting_algorithms/Comb_sort',
#  '/wiki/Sorting_algorithms/Counting_sort',
#  '/wiki/Sorting_algorithms/Gnome_sort',
#  '/wiki/Sorting_algorithms/Heapsort',
#  '/wiki/Sorting_algorithms/Insertion_sort',
#  '/wiki/Sorting_algorithms/Merge_sort',
#  '/wiki/Sorting_algorithms/Pancake_sort',
#  '/wiki/Sorting_algorithms/Permutation_sort',
#  '/wiki/Sorting_algorithms/Quicksort',
#  '/wiki/Sorting_algorithms/Radix_sort',
#  '/wiki/Sorting_algorithms/Selection_sort',
#  '/wiki/Sorting_algorithms/Shell_sort',
#  '/wiki/Sorting_algorithms/Sleep_sort',
#  '/wiki/Sorting_algorithms/Stooge_sort',
#  '/wiki/Sorting_algorithms/Strand_sort',
#  '/wiki/Soundex',
#  '/wiki/Sparkline_in_unicode',
#  '/wiki/Special_characters',
#  '/wiki/Special_variables',
#  '/wiki/Speech_synthesis',
#  '/wiki/Spiral_matrix',
#  '/wiki/SQL-based_authentication',
#  '/wiki/Stable_marriage_problem',
#  '/wiki/Stack',
#  '/wiki/Stack_traces',
#  '/wiki/Stair-climbing_puzzle',
#  '/wiki/Standard_deviation',
#  '/wiki/Start_from_a_main_routine',
#  '/wiki/State_name_puzzle',
#  '/wiki/Statistics/Basic',
#  '/wiki/Stem-and-leaf_plot',
#  '/wiki/Stern-Brocot_sequence',
#  '/wiki/String_append',
#  '/wiki/String_case',
#  '/wiki/String_comparison',
#  '/wiki/String_concatenation',
#  '/wiki/String_interpolation_(included)',
#  '/wiki/String_length',
#  '/wiki/String_matching',
#  '/wiki/String_prepend',
#  '/wiki/Strip_a_set_of_characters_from_a_string',
#  '/wiki/Strip_block_comments',
#  '/wiki/Strip_comments_from_a_string',
#  '/wiki/Strip_control_codes_and_extended_characters_from_a_string',
#  '/wiki/Strip_whitespace_from_a_string/Top_and_tail',
#  '/wiki/Subleq',
#  '/wiki/Substring',
#  '/wiki/Substring/Top_and_tail',
#  '/wiki/Subtractive_generator',
#  '/wiki/Sudoku',
#  '/wiki/Sum_and_product_of_an_array',
#  '/wiki/Sum_digits_of_an_integer',
#  '/wiki/Sum_multiples_of_3_and_5',
#  '/wiki/Sum_of_a_series',
#  '/wiki/Sum_of_squares',
#  '/wiki/Sutherland-Hodgman_polygon_clipping',
#  '/wiki/Symmetric_difference',
#  '/wiki/Synchronous_concurrency',
#  '/wiki/System_time',
#  '/wiki/Table_creation/Postal_addresses',
#  '/wiki/Take_notes_on_the_command_line',
#  '/wiki/Temperature_conversion',
#  '/wiki/Terminal_control/Clear_the_screen',
#  '/wiki/Terminal_control/Coloured_text',
#  '/wiki/Terminal_control/Cursor_movement',
#  '/wiki/Terminal_control/Cursor_positioning',
#  '/wiki/Terminal_control/Dimensions',
#  '/wiki/Terminal_control/Display_an_extended_character',
#  '/wiki/Terminal_control/Hiding_the_cursor',
#  '/wiki/Terminal_control/Inverse_video',
#  '/wiki/Terminal_control/Positional_read',
#  '/wiki/Terminal_control/Preserve_screen',
#  '/wiki/Terminal_control/Ringing_the_terminal_bell',
#  '/wiki/Terminal_control/Unicode_output',
#  '/wiki/Ternary_logic',
#  '/wiki/Test_a_function',
#  '/wiki/Text_processing/1',
#  '/wiki/Text_processing/2',
#  '/wiki/Text_processing/Max_licenses_in_use',
#  '/wiki/Textonyms',
#  '/wiki/The_ISAAC_Cipher',
#  '/wiki/The_Twelve_Days_of_Christmas',
#  '/wiki/Thiele%27s_interpolation_formula',
#  '/wiki/Tic-tac-toe',
#  '/wiki/Time_a_function',
#  '/wiki/Tokenize_a_string',
#  '/wiki/Top_rank_per_group',
#  '/wiki/Topic_variable',
#  '/wiki/Topological_sort',
#  '/wiki/Topswops',
#  '/wiki/Total_circles_area',
#  '/wiki/Towers_of_Hanoi',
#  '/wiki/Trabb_Pardo%E2%80%93Knuth_algorithm',
#  '/wiki/Tree_traversal',
#  '/wiki/Trigonometric_functions',
#  '/wiki/Truncatable_primes',
#  '/wiki/Truncate_a_file',
#  '/wiki/Twelve_statements',
#  '/wiki/Ulam_spiral_(for_primes)',
#  '/wiki/Unbias_a_random_generator',
#  '/wiki/Undefined_values',
#  '/wiki/Unicode_strings',
#  '/wiki/Unicode_variable_names',
#  '/wiki/Universal_Turing_machine',
#  '/wiki/Unix/ls',
#  '/wiki/Update_a_configuration_file',
#  '/wiki/URL_decoding',
#  '/wiki/URL_encoding',
#  '/wiki/Use_another_language_to_call_a_function',
#  '/wiki/User_input/Graphical',
#  '/wiki/User_input/Text',
#  '/wiki/Vampire_number',
#  '/wiki/Van_der_Corput_sequence',
#  '/wiki/Variable_size/Get',
#  '/wiki/Variable_size/Set',
#  '/wiki/Variable-length_quantity',
#  '/wiki/Variables',
#  '/wiki/Variadic_function',
#  '/wiki/Vector_products',
#  '/wiki/Verify_distribution_uniformity/Chi-squared_test',
#  '/wiki/Verify_distribution_uniformity/Naive',
#  '/wiki/Video_display_modes',
#  '/wiki/Vigen%C3%A8re_cipher',
#  '/wiki/Vigen%C3%A8re_cipher/Cryptanalysis',
#  '/wiki/Visualize_a_tree',
#  '/wiki/Vogel%27s_approximation_method',
#  '/wiki/Voronoi_diagram',
#  '/wiki/Walk_a_directory/Non-recursively',
#  '/wiki/Walk_a_directory/Recursively',
#  '/wiki/Web_scraping',
#  '/wiki/Window_creation',
#  '/wiki/Window_creation/X11',
#  '/wiki/Window_management',
#  '/wiki/Wireworld',
#  '/wiki/Word_wrap',
#  '/wiki/World_Cup_group_stage',
#  '/wiki/Write_float_arrays_to_a_text_file',
#  '/wiki/Write_language_name_in_3D_ASCII',
#  '/wiki/Write_to_Windows_event_log',
#  '/wiki/Xiaolin_Wu%27s_line_algorithm',
#  '/wiki/XML/DOM_serialization',
#  '/wiki/XML/Input',
#  '/wiki/XML/Output',
#  '/wiki/XML/XPath',
#  '/wiki/Y_combinator',
#  '/wiki/Yahoo!_search_interface',
#  '/wiki/Yin_and_yang',
#  '/wiki/Zebra_puzzle',
#  '/wiki/Zeckendorf_arithmetic',
#  '/wiki/Zeckendorf_number_representation',
#  '/wiki/Zero_to_the_zero_power',
#  '/wiki/Zhang-Suen_thinning_algorithm',
#  '/wiki/Zig-zag_matrix',
#  '/wiki/Category:Programming_Tasks',
#  '/wiki/Category_talk:Programming_Tasks',
#  '/wiki/Category:Programming_Tasks',
#  '/wiki/Rosetta_Code',
#  '/wiki/Special:WebChat',
#  '/wiki/Rosetta_Code:Village_Pump',
#  '/wiki/Rosetta_Code:Finances',
#  '/wiki/Category:Programming_Languages',
#  '/wiki/Category:Programming_Tasks',
#  '/wiki/Special:RecentChanges',
#  '/wiki/Help:Similar_Sites',
#  '/wiki/Special:Random',
#  '/wiki/Special:WhatLinksHere/Category:Programming_Tasks',
#  '/wiki/Special:RecentChangesLinked/Category:Programming_Tasks',
#  '/wiki/Special:SpecialPages',
#  '/wiki/Special:Browse/Category:Programming_Tasks',
#  '/wiki/Rosetta_Code:Privacy_policy',
#  '/wiki/Rosetta_Code:About',
#  '/wiki/Rosetta_Code:General_disclaimer']

# %%
web_scraper = make_links_list(500)

# %%
web_scraper
# Out:
# ['http://www.rosettacode.org/wiki/Sorting_algorithms/Pancake_sort',
#  'http://www.rosettacode.org/wiki/Power_set',
#  'http://www.rosettacode.org/wiki/Rosetta_Code/Find_unimplemented_tasks',
#  'http://www.rosettacode.org/wiki/Associative_array/Iteration',
#  'http://www.rosettacode.org/wiki/Fibonacci_word',
#  'http://www.rosettacode.org/wiki/Dot_product',
#  'http://www.rosettacode.org/wiki/String_prepend',
#  'http://www.rosettacode.org/wiki/Vampire_number',
#  'http://www.rosettacode.org/wiki/String_matching',
#  'http://www.rosettacode.org/wiki/Introspection',
#  'http://www.rosettacode.org/wiki/Empty_directory',
#  'http://www.rosettacode.org/wiki/Globally_replace_text_in_several_files',
#  'http://www.rosettacode.org/wiki/Pinstripe/Display',
#  'http://www.rosettacode.org/wiki/Range_extraction',
#  'http://www.rosettacode.org/wiki/Use_another_language_to_call_a_function',
#  'http://www.rosettacode.org/wiki/Echo_server',
#  'http://www.rosettacode.org/wiki/File_size',
#  'http://www.rosettacode.org/wiki/OpenGL',
#  'http://www.rosettacode.org/wiki/Arithmetic-geometric_mean/Calculate_Pi',
#  'http://www.rosettacode.org/wiki/Zhang-Suen_thinning_algorithm',
#  'http://www.rosettacode.org/wiki/Loops/Nested',
#  'http://www.rosettacode.org/wiki/Window_creation/X11',
#  'http://www.rosettacode.org/wiki/Honeycombs',
#  'http://www.rosettacode.org/wiki/Knight%27s_tour',
#  'http://www.rosettacode.org/wiki/Bulls_and_cows/Player',
#  'http://www.rosettacode.org/wiki/Category:Programming_Languages',
#  'http://www.rosettacode.org/wiki/Dining_philosophers',
#  'http://www.rosettacode.org/wiki/Palindrome_detection',
#  'http://www.rosettacode.org/wiki/Bitmap/PPM_conversion_through_a_pipe',
#  'http://www.rosettacode.org/wiki/Symmetric_difference',
#  'http://www.rosettacode.org/wiki/Create_a_file_on_magnetic_tape',
#  'http://www.rosettacode.org/wiki/Sailors,_coconuts_and_a_monkey_problem',
#  'http://www.rosettacode.org/wiki/Pig_the_dice_game',
#  'http://www.rosettacode.org/wiki/Binary_search',
#  'http://www.rosettacode.org/wiki/Queue/Definition',
#  'http://www.rosettacode.org/wiki/Scope/Function_names_and_labels',
#  'http://www.rosettacode.org/wiki/Execute_SNUSP',
#  'http://www.rosettacode.org/wiki/Y_combinator',
#  'http://www.rosettacode.org/wiki/Greyscale_bars/Display',
#  'http://www.rosettacode.org/wiki/Parallel_calculations',
#  'http://www.rosettacode.org/wiki/Doubly-linked_list/Traversal',
#  'http://www.rosettacode.org/wiki/Assertions',
#  'http://www.rosettacode.org/wiki/FizzBuzz',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Stooge_sort',
#  'http://www.rosettacode.org/wiki/Sort_disjoint_sublist',
#  'http://www.rosettacode.org/wiki/Man_or_boy_test',
#  'http://www.rosettacode.org/wiki/Doubly-linked_list/Element_insertion',
#  'http://www.rosettacode.org/wiki/Combinations',
#  'http://www.rosettacode.org/wiki/Find_limit_of_recursion',
#  'http://www.rosettacode.org/wiki/Bitcoin/public_point_to_address',
#  'http://www.rosettacode.org/wiki/Abstract_type',
#  'http://www.rosettacode.org/wiki/Bitmap/Histogram',
#  'http://www.rosettacode.org/wiki/Penney%27s_game',
#  'http://www.rosettacode.org/wiki/OLE_Automation',
#  'http://www.rosettacode.org/wiki/File_input/output',
#  'http://www.rosettacode.org/wiki/Fractran',
#  'http://www.rosettacode.org/wiki/Video_display_modes',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Radix_sort',
#  'http://www.rosettacode.org/wiki/Strip_a_set_of_characters_from_a_string',
#  'http://www.rosettacode.org/wiki/Knapsack_problem/0-1',
#  'http://www.rosettacode.org/wiki/Variable_size/Get',
#  'http://www.rosettacode.org/wiki/Binary_digits',
#  'http://www.rosettacode.org/wiki/Read_a_file_line_by_line',
#  'http://www.rosettacode.org/wiki/Create_a_file',
#  'http://www.rosettacode.org/wiki/Command-line_arguments',
#  'http://www.rosettacode.org/wiki/Ordered_Partitions',
#  'http://www.rosettacode.org/wiki/Send_email',
#  'http://www.rosettacode.org/wiki/Look-and-say_sequence',
#  'http://www.rosettacode.org/wiki/Operator_precedence',
#  'http://www.rosettacode.org/wiki/Address_of_a_variable',
#  'http://www.rosettacode.org/wiki/Happy_numbers',
#  'http://www.rosettacode.org/wiki/Walk_a_directory/Non-recursively',
#  'http://www.rosettacode.org/wiki/Multiplicative_order',
#  'http://www.rosettacode.org/wiki/Rosetta_Code:Finances',
#  'http://www.rosettacode.org/wiki/File_modification_time',
#  'http://www.rosettacode.org/wiki/Executable_library',
#  'http://www.rosettacode.org/wiki/Detect_division_by_zero',
#  'http://www.rosettacode.org/wiki/Delete_a_file',
#  'http://www.rosettacode.org/wiki/Pi',
#  'http://www.rosettacode.org/wiki/Terminal_control/Ringing_the_terminal_bell',
#  'http://www.rosettacode.org/wiki/Count_the_coins',
#  'http://www.rosettacode.org/wiki/Zero_to_the_zero_power',
#  'http://www.rosettacode.org/wiki/Rosetta_Code:About',
#  'http://www.rosettacode.org/wiki/Van_der_Corput_sequence',
#  'http://www.rosettacode.org/wiki/Solve_a_Hidato_puzzle',
#  'http://www.rosettacode.org/wiki/Random_number_generator_(included)',
#  'http://www.rosettacode.org/wiki/HTTPS/Client-authenticated',
#  'http://www.rosettacode.org/wiki/Mutual_recursion',
#  'http://www.rosettacode.org/wiki/Boolean_values',
#  'http://www.rosettacode.org/wiki/Conjugate_transpose',
#  'http://www.rosettacode.org/wiki/Run-length_encoding',
#  'http://www.rosettacode.org/wiki/Identity_matrix',
#  'http://www.rosettacode.org/wiki/Anagrams',
#  'http://www.rosettacode.org/wiki/Runge-Kutta_method',
#  'http://www.rosettacode.org/wiki/Mandelbrot_set',
#  'http://www.rosettacode.org/wiki/Zeckendorf_number_representation',
#  'http://www.rosettacode.org/wiki/Literals/Integer',
#  'http://www.rosettacode.org/wiki/RSA_code',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Permutation_sort',
#  'http://www.rosettacode.org/wiki/Euler_method',
#  'http://www.rosettacode.org/wiki/Average_loop_length',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Bogosort',
#  'http://www.rosettacode.org/wiki/Floyd%27s_triangle',
#  'http://www.rosettacode.org/wiki/Terminal_control/Hiding_the_cursor',
#  'http://www.rosettacode.org/wiki/Loop_over_multiple_arrays_simultaneously',
#  'http://www.rosettacode.org/wiki/Break_OO_privacy',
#  'http://www.rosettacode.org/wiki/Aliquot_sequence_classifications',
#  'http://www.rosettacode.org/wiki/Fibonacci_sequence',
#  'http://www.rosettacode.org/wiki/Determine_if_only_one_instance_is_running',
#  'http://www.rosettacode.org/wiki/Roman_numerals/Decode',
#  'http://www.rosettacode.org/wiki/Phrase_reversals',
#  'http://www.rosettacode.org/wiki/Create_an_HTML_table',
#  'http://www.rosettacode.org/wiki/XML/Output',
#  'http://www.rosettacode.org/wiki/Stack',
#  'http://www.rosettacode.org/wiki/Permutations/Derangements',
#  'http://www.rosettacode.org/wiki/Start_from_a_main_routine',
#  'http://www.rosettacode.org/wiki/Integer_sequence',
#  'http://www.rosettacode.org/wiki/Evolutionary_algorithm',
#  'http://www.rosettacode.org/wiki/Array_concatenation',
#  'http://www.rosettacode.org/wiki/Subleq',
#  'http://www.rosettacode.org/wiki/Primality_by_trial_division',
#  'http://www.rosettacode.org/wiki/RIPEMD-160',
#  'http://www.rosettacode.org/wiki/Haversine_formula',
#  'http://www.rosettacode.org/wiki/Jump_anywhere',
#  'http://www.rosettacode.org/wiki/Environment_variables',
#  'http://www.rosettacode.org/wiki/Caesar_cipher',
#  'http://www.rosettacode.org/wiki/Walk_a_directory/Recursively',
#  'http://www.rosettacode.org/wiki/Bitmap/Write_a_PPM_file',
#  'http://www.rosettacode.org/wiki/Matrix_arithmetic',
#  'http://www.rosettacode.org/wiki/Enumerations',
#  'http://www.rosettacode.org/wiki/Gamma_function',
#  'http://www.rosettacode.org/wiki/Draw_a_cuboid',
#  'http://www.rosettacode.org/wiki/Terminal_control/Unicode_output',
#  'http://www.rosettacode.org/wiki/Hash_join',
#  'http://www.rosettacode.org/wiki/Anagrams/Deranged_anagrams',
#  'http://www.rosettacode.org/wiki/Terminal_control/Preserve_screen',
#  'http://www.rosettacode.org/wiki/Help:Similar_Sites',
#  'http://www.rosettacode.org/wiki/Program_termination',
#  'http://www.rosettacode.org/wiki/ABC_Problem',
#  'http://www.rosettacode.org/wiki/Inverted_syntax',
#  'http://www.rosettacode.org/wiki/SOAP',
#  'http://www.rosettacode.org/wiki/Top_rank_per_group',
#  'http://www.rosettacode.org/wiki/Calendar',
#  'http://www.rosettacode.org/wiki/Sort_an_array_of_composite_structures',
#  'http://www.rosettacode.org/wiki/Doubly-linked_list/Element_definition',
#  'http://www.rosettacode.org/wiki/Multisplit',
#  'http://www.rosettacode.org/wiki/Nth_root',
#  'http://www.rosettacode.org/wiki/Concurrent_computing',
#  'http://www.rosettacode.org/wiki/List_comprehensions',
#  'http://www.rosettacode.org/wiki/Order_two_numerical_lists',
#  'http://www.rosettacode.org/wiki/Towers_of_Hanoi',
#  'http://www.rosettacode.org/wiki/Bitmap/Midpoint_circle_algorithm',
#  'http://www.rosettacode.org/wiki/Doubly-linked_list/Definition',
#  'http://www.rosettacode.org/wiki/Pinstripe/Printer',
#  'http://www.rosettacode.org/wiki/Multiple_regression',
#  'http://www.rosettacode.org/wiki/Topological_sort',
#  'http://www.rosettacode.org/wiki/Collections',
#  'http://www.rosettacode.org/wiki/Compound_data_type',
#  'http://www.rosettacode.org/wiki/Bitmap/Read_an_image_through_a_pipe',
#  'http://www.rosettacode.org/wiki/Knapsack_problem/Continuous',
#  'http://www.rosettacode.org/wiki/Cholesky_decomposition',
#  'http://www.rosettacode.org/wiki/Monte_Carlo_methods',
#  'http://www.rosettacode.org/wiki/Best_shuffle',
#  'http://www.rosettacode.org/wiki/Synchronous_concurrency',
#  'http://www.rosettacode.org/wiki/Strip_comments_from_a_string',
#  'http://www.rosettacode.org/wiki/Write_float_arrays_to_a_text_file',
#  'http://www.rosettacode.org/wiki/Sum_of_squares',
#  'http://www.rosettacode.org/wiki/Add_a_variable_to_a_class_instance_at_runtime',
#  'http://www.rosettacode.org/wiki/Singly-linked_list/Element_definition',
#  'http://www.rosettacode.org/wiki/Terminal_control/Dimensions',
#  'http://www.rosettacode.org/wiki/Call_a_function_in_a_shared_library',
#  'http://www.rosettacode.org/wiki/MD5/Implementation',
#  'http://www.rosettacode.org/wiki/Plot_coordinate_pairs',
#  'http://www.rosettacode.org/wiki/Currying',
#  'http://www.rosettacode.org/wiki/Continued_fraction/Arithmetic/Construct_from_rational_number',
#  'http://www.rosettacode.org/wiki/Generic_swap',
#  'http://www.rosettacode.org/wiki/User_input/Text',
#  'http://www.rosettacode.org/wiki/Pernicious_numbers',
#  'http://www.rosettacode.org/wiki/Knuth_shuffle',
#  'http://www.rosettacode.org/wiki/Keyboard_input/Obtain_a_Y_or_N_response',
#  'http://www.rosettacode.org/wiki/Events',
#  'http://www.rosettacode.org/wiki/Set_puzzle',
#  'http://www.rosettacode.org/wiki/Vigen%C3%A8re_cipher',
#  'http://www.rosettacode.org/wiki/Bitcoin/address_validation',
#  'http://www.rosettacode.org/wiki/Convert_decimal_number_to_rational',
#  'http://www.rosettacode.org/wiki/Variable_size/Set',
#  'http://www.rosettacode.org/wiki/Pick_random_element',
#  'http://www.rosettacode.org/wiki/Five_weekends',
#  'http://www.rosettacode.org/wiki/Interactive_programming',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Cocktail_sort',
#  'http://www.rosettacode.org/wiki/Call_a_function',
#  'http://www.rosettacode.org/wiki/Terminal_control/Positional_read',
#  'http://www.rosettacode.org/wiki/SHA-256',
#  'http://www.rosettacode.org/wiki/Ray-casting_algorithm',
#  'http://www.rosettacode.org/wiki/Call_an_object_method',
#  'http://www.rosettacode.org/wiki/Rename_a_file',
#  'http://www.rosettacode.org/wiki/Random_numbers',
#  'http://www.rosettacode.org/wiki/Balanced_brackets',
#  'http://www.rosettacode.org/wiki/Bernoulli_numbers',
#  'http://www.rosettacode.org/wiki/System_time',
#  'http://www.rosettacode.org/wiki/Flow-control_structures',
#  'http://www.rosettacode.org/wiki/Knuth%27s_algorithm_S',
#  'http://www.rosettacode.org/wiki/Generate_Chess960_starting_position',
#  'http://www.rosettacode.org/wiki/Terminal_control/Display_an_extended_character',
#  'http://www.rosettacode.org/wiki/Continued_fraction/Arithmetic/G(matrix_NG,_Contined_Fraction_N1,_Contined_Fraction_N2)',
#  'http://www.rosettacode.org/wiki/Deepcopy',
#  'http://www.rosettacode.org/wiki/String_comparison',
#  'http://www.rosettacode.org/wiki/Greatest_element_of_a_list',
#  'http://www.rosettacode.org/wiki/Polynomial_regression',
#  'http://www.rosettacode.org/wiki/9_billion_names_of_God_the_integer',
#  'http://www.rosettacode.org/wiki/Odd_word_problem',
#  'http://www.rosettacode.org/wiki/Read_a_configuration_file',
#  'http://www.rosettacode.org/wiki/Yin_and_yang',
#  'http://www.rosettacode.org/wiki/Fast_Fourier_transform',
#  'http://www.rosettacode.org/wiki/Ternary_logic',
#  'http://www.rosettacode.org/wiki/Prime_decomposition',
#  'http://www.rosettacode.org/wiki/Combinations_and_permutations',
#  'http://www.rosettacode.org/wiki/Rosetta_Code:Village_Pump',
#  'http://www.rosettacode.org/wiki/World_Cup_group_stage',
#  'http://www.rosettacode.org/wiki/Enforced_immutability',
#  'http://www.rosettacode.org/wiki/Dutch_national_flag_problem',
#  'http://www.rosettacode.org/wiki/Search_a_list',
#  'http://www.rosettacode.org/wiki/Morse_code',
#  'http://www.rosettacode.org/wiki/Semordnilap',
#  'http://www.rosettacode.org/wiki/State_name_puzzle',
#  'http://www.rosettacode.org/wiki/Window_creation',
#  'http://www.rosettacode.org/wiki/Queue/Usage',
#  'http://www.rosettacode.org/wiki/Box_the_compass',
#  'http://www.rosettacode.org/wiki/Magic_squares_of_odd_order',
#  'http://www.rosettacode.org/wiki/Here_document',
#  'http://www.rosettacode.org/wiki/Hello_world/Text',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Gnome_sort',
#  'http://www.rosettacode.org/wiki/Loops/Foreach',
#  'http://www.rosettacode.org/wiki/Price_fraction',
#  'http://www.rosettacode.org/wiki/Bitmap/Flood_fill',
#  'http://www.rosettacode.org/wiki/Metronome',
#  'http://www.rosettacode.org/wiki/Window_management',
#  'http://www.rosettacode.org/wiki/Checkpoint_synchronization',
#  'http://www.rosettacode.org/wiki/S-Expressions',
#  'http://www.rosettacode.org/wiki/HTTPS/Authenticated',
#  'http://www.rosettacode.org/wiki/Calendar_-_for_%22REAL%22_programmers',
#  'http://www.rosettacode.org/wiki/Averages/Mean_angle',
#  'http://www.rosettacode.org/wiki/Increment_a_numerical_string',
#  'http://www.rosettacode.org/wiki/Hamming_numbers',
#  'http://www.rosettacode.org/wiki/Terminal_control/Clear_the_screen',
#  'http://www.rosettacode.org/wiki/Count_occurrences_of_a_substring',
#  'http://www.rosettacode.org/wiki/Arrays',
#  'http://www.rosettacode.org/wiki/Chinese_remainder_theorem',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Selection_sort',
#  'http://www.rosettacode.org/wiki/Miller-Rabin_primality_test',
#  'http://www.rosettacode.org/wiki/Stem-and-leaf_plot',
#  'http://www.rosettacode.org/wiki/Sierpinski_triangle',
#  'http://www.rosettacode.org/wiki/Equilibrium_index',
#  'http://www.rosettacode.org/wiki/Soundex',
#  'http://www.rosettacode.org/wiki/Date_manipulation',
#  'http://www.rosettacode.org/wiki/Lucas-Lehmer_test',
#  'http://www.rosettacode.org/wiki/Catmull%E2%80%93Clark_subdivision_surface',
#  'http://www.rosettacode.org/wiki/Text_processing/1',
#  'http://www.rosettacode.org/wiki/Rosetta_Code:Add_a_Task',
#  'http://www.rosettacode.org/wiki/Terminal_control/Cursor_movement',
#  'http://www.rosettacode.org/wiki/Sleep',
#  'http://www.rosettacode.org/wiki/Rep-string',
#  'http://www.rosettacode.org/wiki/Documentation',
#  'http://www.rosettacode.org/wiki/Fractal_tree',
#  'http://www.rosettacode.org/wiki/Color_of_a_screen_pixel',
#  'http://www.rosettacode.org/wiki/Maze_solving',
#  'http://www.rosettacode.org/wiki/Sum_digits_of_an_integer',
#  'http://www.rosettacode.org/wiki/Inverted_index',
#  'http://www.rosettacode.org/wiki/Holidays_related_to_Easter',
#  'http://www.rosettacode.org/wiki/Vector_products',
#  'http://www.rosettacode.org/wiki/Special_characters',
#  'http://www.rosettacode.org/wiki/Stern-Brocot_sequence',
#  'http://www.rosettacode.org/wiki/Catalan_numbers',
#  'http://www.rosettacode.org/wiki/Roman_numerals/Encode',
#  'http://www.rosettacode.org/wiki/Semiprime',
#  'http://www.rosettacode.org/wiki/Reverse_a_string',
#  'http://www.rosettacode.org/wiki/Horner%27s_rule_for_polynomial_evaluation',
#  'http://www.rosettacode.org/wiki/Greatest_common_divisor',
#  'http://www.rosettacode.org/wiki/Speech_synthesis',
#  'http://www.rosettacode.org/wiki/Solve_a_Hopido_puzzle',
#  'http://www.rosettacode.org/wiki/Loops/For_with_a_specified_step',
#  'http://www.rosettacode.org/wiki/Shell_one-liner',
#  'http://www.rosettacode.org/wiki/String_case',
#  'http://www.rosettacode.org/wiki/Special:WebChat',
#  'http://www.rosettacode.org/wiki/Determine_if_a_string_is_numeric',
#  'http://www.rosettacode.org/wiki/Pythagorean_triples',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Insertion_sort',
#  'http://www.rosettacode.org/wiki/Count_in_octal',
#  'http://www.rosettacode.org/wiki/Arena_storage_pool',
#  'http://www.rosettacode.org/wiki/Word_wrap',
#  'http://www.rosettacode.org/wiki/Averages/Median',
#  'http://www.rosettacode.org/wiki/Function_composition',
#  'http://www.rosettacode.org/wiki/Hickerson_series_of_almost_integers',
#  'http://www.rosettacode.org/wiki/Machine_code',
#  'http://www.rosettacode.org/wiki/Active_Directory/Search_for_a_user',
#  'http://www.rosettacode.org/wiki/Stair-climbing_puzzle',
#  'http://www.rosettacode.org/wiki/Modular_inverse',
#  'http://www.rosettacode.org/wiki/Pascal_matrix_generation',
#  'http://www.rosettacode.org/wiki/Time_a_function',
#  'http://www.rosettacode.org/wiki/Matrix_transposition',
#  'http://www.rosettacode.org/wiki/Hello_world/Web_server',
#  'http://www.rosettacode.org/wiki/Trigonometric_functions',
#  'http://www.rosettacode.org/wiki/URL_decoding',
#  'http://www.rosettacode.org/wiki/Non-decimal_radices/Input',
#  'http://www.rosettacode.org/wiki/Sierpinski_carpet',
#  'http://www.rosettacode.org/wiki/Inheritance/Multiple',
#  'http://www.rosettacode.org/wiki/Text_processing/Max_licenses_in_use',
#  'http://www.rosettacode.org/wiki/Circles_of_given_radius_through_two_points',
#  'http://www.rosettacode.org/wiki/Web_scraping',
#  'http://www.rosettacode.org/wiki/Simulate_input/Mouse',
#  'http://www.rosettacode.org/wiki/Roots_of_unity',
#  'http://www.rosettacode.org/wiki/Digital_root',
#  'http://www.rosettacode.org/wiki/Sierpinski_triangle/Graphical',
#  'http://www.rosettacode.org/wiki/Sequence_of_non-squares',
#  'http://www.rosettacode.org/wiki/Spiral_matrix',
#  'http://www.rosettacode.org/wiki/Strip_block_comments',
#  'http://www.rosettacode.org/wiki/Hello_world/Newbie',
#  'http://www.rosettacode.org/wiki/Program_name',
#  'http://www.rosettacode.org/wiki/Guess_the_number',
#  'http://www.rosettacode.org/wiki/Infinity',
#  'http://www.rosettacode.org/wiki/Median_filter',
#  'http://www.rosettacode.org/wiki/Josephus_problem',
#  'http://www.rosettacode.org/wiki/Sort_an_integer_array',
#  'http://www.rosettacode.org/wiki/Align_columns',
#  'http://www.rosettacode.org/wiki/Primes_-_allocate_descendants_to_their_ancestors',
#  'http://www.rosettacode.org/wiki/Execute_a_system_command',
#  'http://www.rosettacode.org/wiki/Sequence_of_primes_by_Trial_Division',
#  'http://www.rosettacode.org/wiki/Function_definition',
#  'http://www.rosettacode.org/wiki/Continued_fraction/Arithmetic/G(matrix_NG,_Contined_Fraction_N)',
#  'http://www.rosettacode.org/wiki/Parsing/RPN_to_infix_conversion',
#  'http://www.rosettacode.org/wiki/Hough_transform',
#  'http://www.rosettacode.org/wiki/CSV_to_HTML_translation',
#  'http://www.rosettacode.org/wiki/Extreme_floating_point_values',
#  'http://www.rosettacode.org/wiki/Knapsack_problem/Unbounded',
#  'http://www.rosettacode.org/wiki/AKS_test_for_primes',
#  'http://www.rosettacode.org/wiki/Monty_Hall_problem',
#  'http://www.rosettacode.org/wiki/Old_lady_swallowed_a_fly',
#  'http://www.rosettacode.org/wiki/DNS_query',
#  'http://www.rosettacode.org/wiki/Rot-13',
#  'http://www.rosettacode.org/wiki/Execute_Brain****',
#  'http://www.rosettacode.org/wiki/Almost_prime',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Merge_sort',
#  'http://www.rosettacode.org/wiki/Animate_a_pendulum',
#  'http://www.rosettacode.org/wiki/Pascal%27s_triangle',
#  'http://www.rosettacode.org/wiki/Image_noise',
#  'http://www.rosettacode.org/wiki/Atomic_updates',
#  'http://www.rosettacode.org/wiki/Numerical_integration',
#  'http://www.rosettacode.org/wiki/Longest_string_challenge',
#  'http://www.rosettacode.org/wiki/Loops/While',
#  'http://www.rosettacode.org/wiki/Total_circles_area',
#  'http://www.rosettacode.org/wiki/Evaluate_binomial_coefficients',
#  'http://www.rosettacode.org/wiki/Regular_expressions',
#  'http://www.rosettacode.org/wiki/Subtractive_generator',
#  'http://www.rosettacode.org/wiki/Real_constants_and_functions',
#  'http://www.rosettacode.org/wiki/Formal_power_series',
#  'http://www.rosettacode.org/wiki/Respond_to_an_unknown_method_call',
#  'http://www.rosettacode.org/wiki/Multiplication_tables',
#  'http://www.rosettacode.org/wiki/Object_serialization',
#  'http://www.rosettacode.org/wiki/Heronian_triangles',
#  'http://www.rosettacode.org/wiki/Sparkline_in_unicode',
#  'http://www.rosettacode.org/wiki/Bitmap/Read_a_PPM_file',
#  'http://www.rosettacode.org/wiki/Averages/Simple_moving_average',
#  'http://www.rosettacode.org/wiki/History_variables',
#  'http://www.rosettacode.org/wiki/Rosetta_Code:Privacy_policy',
#  'http://www.rosettacode.org/wiki/Anonymous_recursion',
#  'http://www.rosettacode.org/wiki/Compile-time_calculation',
#  'http://www.rosettacode.org/wiki/Strip_whitespace_from_a_string/Top_and_tail',
#  'http://www.rosettacode.org/wiki/Rosetta_Code:General_disclaimer',
#  'http://www.rosettacode.org/wiki/Bulls_and_cows',
#  'http://www.rosettacode.org/wiki/Narcissist',
#  'http://www.rosettacode.org/wiki/SEDOLs',
#  'http://www.rosettacode.org/wiki/Gaussian_elimination',
#  'http://www.rosettacode.org/wiki/Associative_array/Creation',
#  'http://www.rosettacode.org/wiki/Deconvolution/2D%2B',
#  'http://www.rosettacode.org/wiki/Reduced_row_echelon_form',
#  'http://www.rosettacode.org/wiki/Comments',
#  'http://www.rosettacode.org/wiki/Hailstone_sequence',
#  'http://www.rosettacode.org/wiki/Maze_generation',
#  'http://www.rosettacode.org/wiki/Digital_root/Multiplicative_digital_root',
#  'http://www.rosettacode.org/wiki/Rosetta_Code/Rank_languages_by_popularity',
#  'http://www.rosettacode.org/wiki/XML/XPath',
#  'http://www.rosettacode.org/wiki/Hostname',
#  'http://www.rosettacode.org/wiki/Input_loop',
#  'http://www.rosettacode.org/wiki/Minesweeper_game',
#  'http://www.rosettacode.org/wiki/Canny_edge_detector',
#  'http://www.rosettacode.org/wiki/Read_entire_file',
#  'http://www.rosettacode.org/wiki/Problem_of_Apollonius',
#  'http://www.rosettacode.org/wiki/Call_a_foreign-language_function',
#  'http://www.rosettacode.org/wiki/Rock-paper-scissors',
#  'http://www.rosettacode.org/wiki/Jensen%27s_Device',
#  'http://www.rosettacode.org/wiki/Sokoban',
#  'http://www.rosettacode.org/wiki/Thiele%27s_interpolation_formula',
#  'http://www.rosettacode.org/wiki/Bitmap/B%C3%A9zier_curves/Quadratic',
#  'http://www.rosettacode.org/wiki/Closest-pair_problem',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Bead_sort',
#  'http://www.rosettacode.org/wiki/Percolation/Mean_cluster_density',
#  'http://www.rosettacode.org/wiki/String_concatenation',
#  'http://www.rosettacode.org/wiki/Percentage_difference_between_images',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Strand_sort',
#  'http://www.rosettacode.org/wiki/Polynomial_long_division',
#  'http://www.rosettacode.org/wiki/Truncate_a_file',
#  'http://www.rosettacode.org/wiki/Verify_distribution_uniformity/Chi-squared_test',
#  'http://www.rosettacode.org/wiki/Text_processing/2',
#  'http://www.rosettacode.org/wiki/Null_object',
#  'http://www.rosettacode.org/wiki/Permutation_test',
#  'http://www.rosettacode.org/wiki/Forest_fire',
#  'http://www.rosettacode.org/wiki/Left_factorials',
#  'http://www.rosettacode.org/wiki/Longest_common_subsequence',
#  'http://www.rosettacode.org/wiki/Move-to-front_algorithm',
#  'http://www.rosettacode.org/wiki/Solve_a_Holy_Knight%27s_tour',
#  'http://www.rosettacode.org/wiki/Empty_program',
#  'http://www.rosettacode.org/wiki/Verify_distribution_uniformity/Naive',
#  'http://www.rosettacode.org/wiki/Write_language_name_in_3D_ASCII',
#  'http://www.rosettacode.org/wiki/Sudoku',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Sleep_sort',
#  'http://www.rosettacode.org/wiki/Luhn_test_of_credit_card_numbers',
#  'http://www.rosettacode.org/wiki/Empty_string',
#  'http://www.rosettacode.org/wiki/CRC-32',
#  'http://www.rosettacode.org/wiki/XML/DOM_serialization',
#  'http://www.rosettacode.org/wiki/Letter_frequency',
#  'http://www.rosettacode.org/wiki/Special:RecentChangesLinked/Category:Programming_Tasks',
#  'http://www.rosettacode.org/wiki/Longest_increasing_subsequence',
#  'http://www.rosettacode.org/wiki/Maximum_triangle_path_sum',
#  'http://www.rosettacode.org/wiki/Forward_difference',
#  'http://www.rosettacode.org/wiki/Rosetta_Code',
#  'http://www.rosettacode.org/wiki/Terminal_control/Coloured_text',
#  'http://www.rosettacode.org/wiki/Carmichael_3_strong_pseudoprimes',
#  'http://www.rosettacode.org/wiki/Element-wise_operations',
#  'http://www.rosettacode.org/wiki/Record_sound',
#  'http://www.rosettacode.org/wiki/Paraffins',
#  'http://www.rosettacode.org/wiki/Grayscale_image',
#  'http://www.rosettacode.org/wiki/Polymorphism',
#  'http://www.rosettacode.org/wiki/Show_the_epoch',
#  'http://www.rosettacode.org/wiki/Deal_cards_for_FreeCell',
#  'http://www.rosettacode.org/wiki/Conditional_structures',
#  'http://www.rosettacode.org/wiki/Sort_stability',
#  'http://www.rosettacode.org/wiki/Take_notes_on_the_command_line',
#  'http://www.rosettacode.org/wiki/Voronoi_diagram',
#  'http://www.rosettacode.org/wiki/Zebra_puzzle',
#  'http://www.rosettacode.org/wiki/Horizontal_sundial_calculations',
#  'http://www.rosettacode.org/wiki/Tree_traversal',
#  'http://www.rosettacode.org/wiki/Averages/Mean_time_of_day',
#  'http://www.rosettacode.org/wiki/Rate_counter',
#  'http://www.rosettacode.org/wiki/Order_disjoint_list_items',
#  'http://www.rosettacode.org/wiki/Repeat_a_string',
#  'http://www.rosettacode.org/wiki/99_Bottles_of_Beer',
#  'http://www.rosettacode.org/wiki/Iterated_digits_squaring',
#  'http://www.rosettacode.org/wiki/Sorting_algorithms/Heapsort',
#  'http://www.rosettacode.org/wiki/Logical_operations',
#  'http://www.rosettacode.org/wiki/N%27th',
#  'http://www.rosettacode.org/wiki/Inheritance/Single',
#  'http://www.rosettacode.org/wiki/Non-decimal_radices/Convert',
#  'http://www.rosettacode.org/wiki/Vogel%27s_approximation_method',
#  'http://www.rosettacode.org/wiki/Accumulator_factory',
#  'http://www.rosettacode.org/wiki/Hash_from_two_arrays',
#  'http://www.rosettacode.org/wiki/Strip_control_codes_and_extended_characters_from_a_string',
#  'http://www.rosettacode.org/wiki/Narcissistic_decimal_number',
#  'http://www.rosettacode.org/wiki/Permutations',
#  'http://www.rosettacode.org/wiki/Read_a_specific_line_from_a_file',
#  'http://www.rosettacode.org/wiki/Quaternion_type',
#  'http://www.rosettacode.org/wiki/Substring',
#  'http://www.rosettacode.org/wiki/Pangram_checker',
#  'http://www.rosettacode.org/wiki/HTTPS',
#  'http://www.rosettacode.org/wiki/Conway%27s_Game_of_Life',
#  'http://www.rosettacode.org/wiki/Literals/Floating_point',
#  'http://www.rosettacode.org/wiki/Resistor_mesh',
#  'http://www.rosettacode.org/wiki/Leap_year',
#  'http://www.rosettacode.org/wiki/K-means%2B%2B_clustering',
#  'http://www.rosettacode.org/wiki/Continued_fraction',
#  'http://www.rosettacode.org/wiki/Active_object',
#  'http://www.rosettacode.org/wiki/Number_names',
#  'http://www.rosettacode.org/wiki/Number_reversal_game',
#  'http://www.rosettacode.org/wiki/Arithmetic/Complex',
#  'http://www.rosettacode.org/wiki/Parsing/RPN_calculator_algorithm',
#  'http://www.rosettacode.org/wiki/Multifactorial',
#  'http://www.rosettacode.org/wiki/Hello_world/Newline_omission',
#  'http://www.rosettacode.org/wiki/Unicode_strings',
#  'http://www.rosettacode.org/wiki/Greatest_subsequential_sum',
#  'http://www.rosettacode.org/wiki/Natural_sorting',
#  'http://www.rosettacode.org/wiki/Short-circuit_evaluation',
#  'http://www.rosettacode.org/wiki/Named_parameters',
#  'http://www.rosettacode.org/wiki/Check_Machin-like_formulas',
#  'http://www.rosettacode.org/wiki/Ranking_methods',
#  'http://www.rosettacode.org/wiki/Sieve_of_Eratosthenes',
#  'http://www.rosettacode.org/wiki/Optional_parameters',
#  'http://www.rosettacode.org/wiki/Bitmap/Bresenham%27s_line_algorithm',
#  'http://www.rosettacode.org/wiki/Random_number_generator_(device)',
#  'http://www.rosettacode.org/wiki/Guess_the_number/With_feedback',
#  'http://www.rosettacode.org/wiki/RCRPG',
#  'http://www.rosettacode.org/wiki/Quickselect_algorithm',
#  'http://www.rosettacode.org/wiki/Percolation/Site_percolation',
#  'http://www.rosettacode.org/wiki/Loops/For',
#  'http://www.rosettacode.org/wiki/Bitwise_operations',
#  'http://www.rosettacode.org/wiki/Hello_world/Standard_error',
#  'http://www.rosettacode.org/wiki/Variables',
#  'http://www.rosettacode.org/wiki/Parse_an_IP_Address',
#  'http://www.rosettacode.org/wiki/One-dimensional_cellular_automata',
#  'http://www.rosettacode.org/wiki/Dinesman%27s_multiple-dwelling_problem',
#  'http://www.rosettacode.org/wiki/Classes',
#  'http://www.rosettacode.org/wiki/Mad_Libs']

# %%
df = scrape_and_clean(5)
df
# Out:
#                 0                                                  1
# 0      autohotkey  BeadSort(data){\tPole:=[]\t, TempObj:=[], Resu...
# 1      autohotkey  for i, val in BeadSort([54,12,87,56,36])\tres ...
# 2               c  #include <stdio.h>#include <stdlib.h> void bea...
# 3             cpp  //this algorithm only works with positive, who...
# 4         clojure  (defn transpose [xs]  (loop [ret [], remain xs...
# 5            lisp   (defun transpose (remain &optional (ret '()))...
# 6               d  program BeadSortTest; {$APPTYPE CONSOLE} uses ...
# 7               d  import std.stdio, std.algorithm, std.range, st...
# 8          eiffel   class\tBEAD_SORT feature \tbead_sort (ar: ARR...
# 9          eiffel    class\tAPPLICATION create\tmake feature \tma...
# 11         erlang  -module(beadsort). -export([sort/1]). sort(L) ...
# 12         erlang  1> beadsort:sort([1,734,24,3,324,324,32,432,42...
# 13         fsharp  open System let removeEmptyLists lists = lists...
# 16        fortran  program BeadSortTest  use iso_fortran_env   ! ...
# 17             go  package main import (    "fmt"    "sync") var ...
# 18         groovy  def beadSort = { list ->    final nPoles = lis...
# 19         groovy  def beadSortVerbose = { list ->    final nPole...
# 20         groovy  println beadSort([23,76,99,58,97,57,35,89,51,3...
# 21        haskell  import Data.List beadSort :: [Int] -> [Int]bea...
# 22        haskell             *Main> beadSort [2,4,1,3,3][4,3,3,2,1]
# 23           icon  procedure main()                     #: demons...
# 24              j                                 bead=: [: +/ #"0&1
# 26              j              bball=: ] (] + [: bead^:2 -) <./ - 1:
# 28           java    public class BeadSort {\tpublic static void ...
# 36        netrexx  /* NetRexx */options replace format comments j...
# 38          ocaml  let rec columns l =  match List.filter ((<>) [...
# 39         octave  function sorted = beadsort(a)  sorted = a;  m ...
# 40         oorexx  in='10 -12 1 0 999 8 2 2 4 4' Do i=1 To words(...
# 41         oorexx  /*REXX program sorts a list of integers using ...
# 42       progress  FUNCTION beadSort RETURNS CHAR (   i_c AS CHAR...
# ..            ...                                                ...
# 222       algol68  # Non-recursive Knight's Tour with Warnsdorff'...
# 223    autohotkey  #SingleInstance, Force#NoEnvSetBatchLines, -1;...
# 224           awk   # syntax: GAWK -f KNIGHTS_TOUR.AWK [-v sr=x] ...
# 227             c  #include <stdio.h>#include <stdlib.h>#include ...
# 228           cpp  #include <iostream>#include <iomanip>#include ...
# 229        csharp  using System;using System.Collections.Generic;...
# 230  coffeescript   graph_tours = (graph, max_num_solutions) ->  ...
# 232             d  import std.stdio, std.algorithm, std.random, s...
# 233             d  import std.stdio, std.math, std.algorithm, std...
# 234        erlang   -module( knights_tour ). -export( [display/1,...
# 236            go  /* Adapted from "Enumerating Knight's Tours us...
# 237       haskell   import System (getArgs)import Data.Char (ord,...
# 238          icon  link printf procedure main(A)ShowTour(KnightsT...
# 239          icon  procedure DumpBoard(B)  #: Dump Board internal...
# 240             j  NB. knight moves for each square of a (y,y) bo...
# 241             j     ktourw 8    NB. solution for an 8 x 8 board...
# 242          java  import java.util.*; public class KnightsTour {...
# 244     locobasic  10 mode 1:defint a-z20 input "Board size: ",si...
# 245           lua  N = 8 moves = { {1,-2},{2,-1},{2,1},{1,2},{-1,...
# 257          perl  use strict;use warnings;# Find a knight's tour...
# 258         perl6  my @board; my $I = 8;my $J = 8;my $F = $I*$J >...
# 261        prolog  % N is the number of lines of the chessboardkn...
# 262        prolog  :- initialization(main).  board_size(8).in_boa...
# 263        python  import copy boardsize=6_kmoves = ((2,1), (1,2)...
# 266          rexx  /*REXX program solves the knight's tour  probl...
# 267          ruby  class Board  Cell = Struct.new(:value, :adj) d...
# 268        scheme   ;;/usr/bin/petite;;encoding:utf-8;;Author:Pan...
# 269           tcl  package require Tcl 8.6;    # For object suppo...
# 270           tcl  set kt [KnightsTour new]$kt constructRandom$kt...
# 271           tcl  set kt [KnightsTour new 7 7]$kt constructFrom ...
#
# [172 rows x 2 columns]

# %%
df.head(20)
# Out:
#              0                                                  1
# 0   autohotkey  BeadSort(data){\tPole:=[]\t, TempObj:=[], Resu...
# 1   autohotkey  for i, val in BeadSort([54,12,87,56,36])\tres ...
# 2            c  #include <stdio.h>#include <stdlib.h> void bea...
# 3          cpp  //this algorithm only works with positive, who...
# 4      clojure  (defn transpose [xs]  (loop [ret [], remain xs...
# 5         lisp   (defun transpose (remain &optional (ret '()))...
# 6            d  program BeadSortTest; {$APPTYPE CONSOLE} uses ...
# 7            d  import std.stdio, std.algorithm, std.range, st...
# 8       eiffel   class\tBEAD_SORT feature \tbead_sort (ar: ARR...
# 9       eiffel    class\tAPPLICATION create\tmake feature \tma...
# 11      erlang  -module(beadsort). -export([sort/1]). sort(L) ...
# 12      erlang  1> beadsort:sort([1,734,24,3,324,324,32,432,42...
# 13      fsharp  open System let removeEmptyLists lists = lists...
# 16     fortran  program BeadSortTest  use iso_fortran_env   ! ...
# 17          go  package main import (    "fmt"    "sync") var ...
# 18      groovy  def beadSort = { list ->    final nPoles = lis...
# 19      groovy  def beadSortVerbose = { list ->    final nPole...
# 20      groovy  println beadSort([23,76,99,58,97,57,35,89,51,3...
# 21     haskell  import Data.List beadSort :: [Int] -> [Int]bea...
# 22     haskell             *Main> beadSort [2,4,1,3,3][4,3,3,2,1]

# %%
new_df = df[df[0]!='text']

# %%
new_df
# Out:
#               0                                                  1
# 0           ada  with Glib;                use Glib;with Cairo;...
# 1           ada   with Display; use Display;with Display.Basic;...
# 2           ahk  #NoEnvSetBatchLines, -1#SingleInstance, Force ...
# 6            lb   WindowWidth  =420WindowHeight =460 nomainwin ...
# 7     purebasic  ; Original by Comtois @ 28/03/06;; Updated/For...
# 8        qbasic  SCREEN 13 ' enter high-color graphic mode ' se...
# 13            c  #include <stdio.h>#include <stdlib.h>#include ...
# 14            c  #include <stdio.h>#include <stdlib.h>#include ...
# 15         java  using System; namespace Sphere {    internal c...
# 16      clojure   (use 'quil.core) (def w 500)(def h 400) (defn...
# 17            d  import std.stdio, std.math, std.algorithm, std...
# 18       delphi   program DrawASphere; {$APPTYPE CONSOLE} uses ...
# 19       delphi   type   TFloat3  = array[0..2] of Float; var  ...
# 21           go  package main import (    "fmt"    "image"    "...
# 22      haskell  import Graphics.Rendering.OpenGL.GLimport Grap...
# 23       unicon  procedure main()W := open("Demo", "gl", "size=...
# 24            j  load 'system/examples/graphics/opengl/simple/s...
# 25            j  'R k ambient' =. 10 2 0.4light =. (% +/&.:*:) ...
# 26         java  public class Sphere{    static char[] shades =...
# 27   javascript  <!DOCTYPE html><html><head><meta charset="utf-...
# 32          lua  require ("math") shades = {'.', ':', '!', '*',...
# 37         perl  use strict;use warnings; my $x = my $y = 255;$...
# 38        perl6  my $x = my $y = 255;$x +|= 1; # must be odd my...
# 42       povray   camera { location  <0.0 , .8 ,-3.0> look_at 0...
# 44       python  import math shades = ('.',':','!','*','o','e',...
# 45       python   import pygamefrom pygame.locals import *impor...
# 46       python   class Tricubic:    def __init__(self,pts):   ...
# 47       python  from visual import *scene.title = "VPython: Dr...
# 48       python   from __future__ import print_function, divisi...
# 50         rexx  /*REXX program expresses a lighted sphere with...
# ..          ...                                                ...
# 151          oz  declare  [HTTPClient] = {Module.link ['x-ozlib...
# 152        perl  package YahooSearch; use Encode;use HTTP::Cook...
# 154      python  import urllibimport re def fix(x):    p = re.c...
# 157        ruby  require 'open-uri'require 'hpricot' SearchResu...
# 159         tcl  package require http proc fix s {    string ma...
# 160         tcl  package require Tcl 8.6 oo::class create WebSe...
# 161         tcl  package require Tcl 8.6 proc yahoo! term {    ...
# 162         tcl  package require Tcl 8.6package require httppac...
# 165           c  #include <stdio.h>#include <stdlib.h>#include ...
# 166        lisp  ;; Assemble the mxn matrix A from the 2D row v...
# 167        lisp  (setf f #2A((-3 -6 -1 8 -6 3 -1 -9 -9 3 -2 5 2...
# 168           d  T[] deconv(T)(in T[] g, in T[] f) pure nothrow...
# 169     fortran   ! Build! Windows: ifort /I "%IFORT_COMPILER11...
# 170     fortran   deconv(f, g) = -8, -9, -3, -1, -6, 7deconv(h,...
# 171          go  package main import "fmt" func main() {    h :...
# 172          go  package main import (    "fmt"    "math"    "m...
# 173     haskell  import Data.List h, f, g :: [Double]h = [-8,-9...
# 174     haskell  *Main> h == deconv1d g fTrue *Main> f == decon...
# 175           j  Ai=: (i.@]  =/ i.@[ -/ i.@>:@-)&#divide=: [ +/...
# 176           j  h=: _8 _9 _3 _1 _6 7f=: _3 _6 _1 8 _6 3 _1 _9 ...
# 177           j     g divide f_8 _9 _3 _1 _6 7   g divide h_3 _...
# 178           j                  divide=: [ +/ .*~ [:%. ] +/ .* Ai
# 179        java  import java.util.Arrays; public class Deconvol...
# 180         lua  function deconvolve(f, g)   local h = setmetat...
# 181         lua   local f = {-3,-6,-1,8,-6,3,-1,-9,-9,3,-2,5,2,...
# 183      matlab  >> h = [-8,-9,-3,-1,-6,7];>> g = [24,75,71,-34...
# 184       perl6  sub deconvolve (@g, @f) {    my $h = 1 + @g - ...
# 187      python  def ToReducedRowEchelonForm( M ):    if not M:...
# 194         tcl  package require Tcl 8.5namespace eval 1D {    ...
# 195         tcl  # Simple pretty-printerproc pp {name nlist} { ...
#
# [126 rows x 2 columns]
